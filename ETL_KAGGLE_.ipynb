# %% [markdown]
# # Extract, Transform and Load (ETL)
# ----------------------
#
# ### Data Fundamentals con Python
#
# #### Enero 2023
#
# **Aurora Cobo Aguilera**
#
# **The Valley**
#
# ----------------------

# %% [markdown]
# ## Ejemplo 1
# Vamos a ver un ejemplo de lo que sería una ETL. Imaginad que tenemos un csv con los siguientes campos:
#
# 1. work_year
# 2. experience_level
# 3. employment_type
# 4. job_title
# 5. salary
# 6. salary_currency
# 7. salary_in_usd
# 8. employee_residence
# 9. remote_ratio
# 10. company_location
# 11. company_size
#
#
# Un ejemplo de una fila del csv podria ser:

# %%
lineaOrigen = '88,2021,SE,FT,Lead Data Analyst,170000,USD,170000,US,100,US,L'

# %% [markdown]
# El objetivo de una ETL es cargar todas las líneas de un fichero y convertirlas o procesarlas para darles el formato que nosotros queramos. Después, debemos guardar esas nuevas líneas convertidas.
#
# Es decir,
#
# 1. Cargar fila
# 2. Transformar fila
# 3. Guardar fila

# %% [markdown]
# Lo primero que has de hacer es identificar cada item de la secuencia de texto con los campos del fichero.

# %% [markdown]
# Una herramienta de utilidad de Python dentro del procesado de cadenas de texto es la función *split()*, ésta permite convertir un texto en una lista en la que cada elemento de la lista es un fragmento del texto original. Los fragmentos se seleccionan en función de un carácter definido que se pasa como parámetro.
#
# Por ejemplo, vamos a separar nuestra cadena con el carácter ','.

# %%
lineaOrigen = lineaOrigen.split(',')

# %% [markdown]
# Ahora, *lineaOrigen* ha pasado a ser una lista con cada uno de los campos. Esta instrucción es muy frecuente pues es muy común encontrar ficheros que separar los elementos con comas.

# %%
print(lineaOrigen)
# Out:
# ['88', '2021', 'SE', 'FT', 'Lead Data Analyst', '170000', 'USD', '170000', 'US', '100', 'US', 'L']

# %% [markdown]
# Si nos fijamos, esta lista tiene

# %%
print(len(lineaOrigen))
# Out:
# 12

# %% [markdown]
# elementos. Mientras que nosotros habíamos definido 11 campos.
#
# > **Ejercicio**: ¿Qué puede significar el elemento sobrante? ¿Cuál de todos ellos es?

# %% [markdown]
# ### Manipulación de la experiencia
#
# Vamos a leer y procesar los campos de interés. Por ejemplo, el campo *experiencia*, puede tener 4 valores posibles (en, mi, se, ex). Una forma de procesarlo sería **codificarlo**.

# %%
experiencia = lineaOrigen[2]

if(experiencia.lower() == 'en'):
    experiencia = 0
elif(experiencia.lower() == 'mi'):
    experiencia = 1
elif(experiencia.lower() == 'se'):
    experiencia = 2
elif(experiencia.lower() == 'ex'):
    experiencia = 3
else:
    experiencia = -1

# %% [markdown]
# En caso de no encontrar ninguno de los caso posibles, nos encontraremos ante un **valor nulo** que hemos decidido codificar con ...
#
# > **Ejercicio**: ¿Con qué valor codificamos los nulos en el ejemplo anterior?

# %% [markdown]
# En este ejemplo, el campo experiencia pasa a valer:

# %%
print(experiencia)
# Out:
# 2

# %% [markdown]
# ### Manipulación del salario
#
# Otro campo que nos interesa es el del salario. Así que primero lo identificamos y guardamos.

# %%
moneda = lineaOrigen[-6]
print(moneda)
# Out:
# USD

# %% [markdown]
# Exacto! Este campo indica el tipo de moneda en el que está recogido la cantidad salarial. También tiene una serie posible de valores (EUR, GBP, USD).
#
# > **Ejercicio**: ¿Cómo denominamos en teoría a estas variables que sólo pueden obtener un conjunto finito de valores?

# %% [markdown]
# Ahora, vamos a unificar la cantidad de salario a euros. Como podemos encontrar salarios en diferentes tipos de monedas, nos interesa que todos estén en la misma para poder comparar y operar de manera correcta. Es como una manera de unificar el sistema de medida. Para ello, mira cuál es el cambio de moneda de hoy en google para las libras y los dólares y pásalo todo a euros.

# %%
if(moneda.lower() == 'eur'):
    salario = float(lineaOrigen[5])# <SOL>
elif(moneda.lower() == 'gbp'):
    salario = float(lineaOrigen[5]) * 1.13 # <SOL>
elif(moneda.lower() == 'usd'):
    salario =  float(lineaOrigen[5]) * 0.93 # <SOL>
else:
    salario = -1

print(salario)
# Out:
# 158100.0

# %% [markdown]
# ### Manipulación del campo *remote*
#
# El campo *remote* hemos decidido dejarlo tal cual.

# %%
remote = int(lineaOrigen[-3])
print(remote)
# Out:
# 100

# %% [markdown]
# ### Manipulación del tamaño
# Por último, nos interesa quedarnos con el campo *company_size*.
#
# > **Ejercicio**: A continuación, obtén dicho campo y guárdalo en alguna variable.

# %%
#<SOL>
tamanyo = lineaOrigen[-1]
print(tamanyo)
#</SOL>
# Out:
# L

# %% [markdown]
# > **Ejercicio**: Para preprocesarlo, codifícalo de manera análoga a los casos anteriores, teniendo en cuenta que los valores posibles son 's', 'm' y 'l', a los que les daremos los valores 0, 1 y 2 respectivamente. -1 de nuevo se usa en caso de que ninguno de los anteriores se dé.

# %%
# <SOL>
if(tamanyo.lower() == 's'):
    tamanyo = 0
elif(tamanyo.lower() == 'm'):
    tamanyo = 1
elif(tamanyo.lower() == 'l'):
    tamanyo = 2
else:
    tamanyo = -1
# <\SOL>

# %%
lineaDestino = [experiencia, salario, remote, tamanyo]
print(lineaDestino)
# Out:
# [2, 158100.0, 100, 2]

# %% [markdown]
# El resultado final debería ser un vector de 4 números, que podría ser la entrada de cualquier modelo de Machine Learning.

# %% [markdown]
# ## Ejemplo 2
#
# A continuación vamos a ver otro ejemplo que vamos a leer del siguiente enlace:
#
# https://www.kaggle.com/datasets/abecklas/fifa-world-cup?select=WorldCupPlayers.csv
#
# Como podrás comprobar, este dataset contiene datos de los jugadores del mundial de fútbol.
#
# > **Ejercicio**: Vamos a aprovechar para registrarnos en kaggle y jugar con la plataforma!

# %% [markdown]
# Fíjate ahora en la descripción de los campos del mismo:
#
# 'RoundID, MatchID, Team Initials, Coach Name, Line-up, Shirt Number, Player Name, Position, Event'
#
# > **Ejercicio**: Descárgate el dataset y abre el fichero referente a los jugadores (WorldCupPlayers.csv). A continuación, elige una línea cualquiera del fichero y cópiala en la siguiente celda en <PEGA AQUÍ>, entre comillas dobles.

# %%
lineaOrigen = "201,1096,FRA,CAUDRON Raoul (FRA),S,0,Andre MASCHINOT,,G43' G87'" #<PEGA AQUÍ>

# %% [markdown]
# Estamos interesados en recolectar y procesar 3 campos, el país del jugador, el nombre y el número de goles que ha metido. Fíjate en la información de cada campo y extrae de la variable *lineaOrigen* dicha información. Pero, vayamos por partes.
#
# > **Ejercicio**: Primero divide el string en una lista donde cada elemento es uno de los campos. Recuerda que puedes usar la función *split*.

# %%
#<SOL>
lineaOrigen = lineaOrigen.split(',')
print(lineaOrigen)
#</SOL>
# Out:
# ['201', '1096', 'FRA', 'CAUDRON Raoul (FRA)', 'S', '0', 'Andre MASCHINOT', '', "G43' G87'"]

# %% [markdown]
# > **Ejercicio**: Ahora guarda el país del jugador y muéstralo con print.

# %%
#<SOL>
pais = lineaOrigen[2]
print(pais)
#</SOL>
# Out:
# FRA

# %% [markdown]
# > **Ejercicio**: Haz lo mismo con el nombre, pero pásalo entero a minúsculas. Guárdalo en la variable 'nombre'.

# %%
#<SOL>
nombre = lineaOrigen[-3].lower()
print(nombre)
#</SOL>
# Out:
# andre maschinot

# %% [markdown]
# > **Ejercicio**: Por último, extrae los goles. Investiga cómo se indica un gol y piensa la manera de contar el total de éstos y guárdalos en una variable llamada 'goles'.

# %%
#<SOL>
goles = len( lineaOrigen[-1].split('G') )-1
print(goles)

#</SOL>
# Out:
# 2

# %%
#<SOL>
num_goles = 0
for caracter in lineaOrigen[-1]:
  if caracter == 'G':
    num_goles = num_goles +1
print(num_goles)
#</SOL>
# Out:
# 2

# %%
#<SOL>
# Más avanzada
goles = len( lineaOrigen[-1].split('G') )-1
restar_golesPropia = len( lineaOrigen[-1].split('OG') )-1
sumar_golesPenalti = len( lineaOrigen[-1].split('P') )-1
goles = goles - restar_golesPropia + sumar_golesPenalti
print(goles)
#</SOL>

# %% [markdown]
# Comprueba que todo ha ido correctamente ejecutando la siguiente línea donde concatena los campos de interés para calcular el resultado final.

# %%
lineaDestino = [pais,nombre,goles]
print(lineaDestino)
# Out:
# ['FRA', 'andre maschinot', 2]

# %% [markdown]
# ## Ejemplo 3
#
# En este ejemplo vamos a tratar un dataset de Población Mundial, del que puedes extraer toda la información en el siguiente enlace:
#
# https://www.kaggle.com/datasets/ahmadjalalmasood123/world-population-dataset
#
# De la misma manera que antes, podemos obtener los nombres de los campos en la primera fila del fichero:
#
# ##### #,Country (or dependency),Population (2022),Yearly change,Net change,Density (P/Km²),Land Area (Km²),Migrants (net),Fert. Rate,Med.Age,Urban Pop %,World Share
#
# En este caso, hemos sustituido las comas de separación por punto y coma para no confundirlas con la coma numérica.

# %%
lineaOrigen = '1;China;1,439,323,776;0.39%;5,540,090;153;9,388,211;-348,399;1.7;38;61%;18.47%'

# %% [markdown]
# Por tanto, ahora el split lo hacemos con ;.

# %%
lineaOrigen = lineaOrigen.split(';')
print(lineaOrigen)
# Out:
# ['1', 'China', '1,439,323,776', '0.39%', '5,540,090', '153', '9,388,211', '-348,399', '1.7', '38', '61%', '18.47%']

# %% [markdown]
# Accedamos al país.

# %%
pais = lineaOrigen[1].lower()
print(pais)
# Out:
# china

# %% [markdown]
# Ahora, a la población, teniendo en cuenta que es un string y que para convertirlo a entero y no confundir las comas por comas decimales, hay que eliminarlas.

# %%
lineaOrigen[2]
# Out:
# '1,439,323,776'

# %%
poblacion = int(lineaOrigen[2].replace(',',''))
print(poblacion)
# Out:
# 1439323776

# %% [markdown]
# Igual con el cambio, campo *Net change*.

# %%
cambioTotal = int(lineaOrigen[4].replace(',',''))
print(cambioTotal)
# Out:
# 5540090

# %% [markdown]
# El signo indica si la población ha cambiado para crecer o decrecer.

# %%
signo = -1

if(cambioTotal > 0):
  signo = 1
print(signo)
# Out:
# 1

# %% [markdown]
# Para la tasa de fertilidad, la vamos a codificar.

# %%
fertil = float(lineaOrigen[-4])

if( fertil > 0 and fertil <= 1):
  fertil = 10
elif( fertil > 1 and fertil <= 1.5):
  fertil = 7.5
elif( fertil > 1.5 and fertil <= 2.1):
  fertil = 5
elif( fertil > 2.1 and fertil <= 3):
  fertil = 4
else:
  fertil = 0

print(fertil)
# Out:
# 5

# %% [markdown]
# > **Ejercicio**: Queremos calcular el número de personas según la densidad de población. Para ello, multiplica la densidad (personas por kilómetro cuadrado) por el tamaño del país.

# %%
densidad = int(lineaOrigen[5].replace(',',''))
area = int(lineaOrigen[6].replace(',',''))
personasKPI = densidad*area #<SOL>
print(personasKPI)
# Out:
# 1436396283

# %% [markdown]
# > **Ejercicio**: Por último, guarda el porcentaje de población mundial. Hazlo sin el símbolo de porcentaje (%) y en un número float.

# %%
porcentajeMundial = float(lineaOrigen[-1].replace('%',''))#<SOL>
print(porcentajeMundial)
# Out:
# 18.47

# %% [markdown]
# Comprobemos el resultado.

# %%
lineaDestino = [pais, poblacion, cambioTotal, signo, personasKPI, fertil, porcentajeMundial]
print(lineaDestino)
# Resultado esperado:
#  china, int(1439323776), int(5540090), 1, 1436396283, 5, 18.47
# Out:
# ['china', 1439323776, 5540090, 1, 1436396283, 5, 18.47]

# %% [markdown]
# > ## Ejercicio
#
# Repite el mismo procedimiento en el siguiente dataset:
#
# https://www.kaggle.com/datasets/nathanlauga/nba-games?select=games.csv
#
#
# Para ello utiliza la siguiente línea ejemplo del fichero *games.csv*.

# %%
rawLine = ["2021-11-17","22100213","Final","1610612766","1610612764","2021","1610612766","97","0.438","0.5","0.313","30","59","1610612764","87","0.367","0.813","0.19","23","48","1"]

# %% [markdown]
# Deberás extraer la fecha, la puntuación del equipo local, la puntuación del visitante y el ganador.

# %%
#<SOL>
fecha = rawLine[0]
print(fecha)

puntuacionLocal = int(rawLine[7])
print(puntuacionLocal)

puntuacionVisitante = int(rawLine[14])
print(puntuacionVisitante)

if int(rawLine[-1]) == 1:
  ganador = rawLine[3]
else:
  ganador = rawLine[4]
print(ganador)

#</SOL>
# Out:
# 2021-11-17
# 97
# 87
# 1610612766

# %%
output = [fecha, puntuacionLocal, puntuacionVisitante, ganador]
print(output)
# Out:
# ['2021-11-17', 97, 87, '1610612766']

# %% [markdown]
# ## Leer ficheros
#
# Es momento de aprender a leer un fichero. Para ello primero tenemos que descargar el fichero deseado, luego cargarlo en el espacio de trabajo del notebook y por último podremos leerlo en python.

# %% [markdown]
# Si ya has hecho los dos primeros pasos, vamos a leer el fichero utilizando una librería llamada *csv*, que tendremos que importar. El resto de líneas también se suelen repetir, puedes reutilizarlas en el futuro. Tendrás que cambiar 'nombreDelFichero.csv' por el deseado y quizás algún parámetro como el que indica el carácter delimitante. Siempre que usemos un archivo csv, el carácter para delimitar suele ser la coma.

# %%
import csv
with open('World Population (2022) .csv', newline='') as csvfile:  #with open('nombreDelFichero.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        print(row)

# %% [markdown]
# ## Proceso completo
#
# Hemos visto parte del proceso ETL, pero en realidad lo que tenemos que hacer es leer un fichero completo y transformar todas las líneas (no sólo una) para después guardarlas en un nuevo fichero.
#
# Veamos ésto paso a paso. Para ello vamos a usar el siguiente dataset.
#
# ######  https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset
#
#
# ### El Algoritmo que vamos a seguir:
# - PASO 1: Transformar 1 línea
# - PASO 2: Subir CSV a la nube y hacer el open() leyendo cada línea en un for
# - PASO 3: Conectar transformación de PASO 1 en el FOR del Paso 2
# - PASO 4: Guardar el fichero finalmente (Fichero Destino)

# %% [markdown]
# ### Paso 1
#
# Vamos a hacer lo que ya conoces.
#
# > **Ejercicio**: Esta vez no tienes que completar código, simplemente intenta traducir lo que se hace y qué campos se cogen.

# %%
''',track_id,artists,album_name,track_name,popularity,duration_ms,explicit,danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,time_signature,track_genre'''

lineaOrigen = '0,5SuOikwiRyPMVoIQDJUgSV,Gen Hoshino,Comedy,Comedy,73,230666,False,0.676,0.461,1,-6.746,0,0.143,0.0322,1.01e-06,0.358,0.715,128,4,acousti'
print(lineaOrigen)  

lineaOrigen = lineaOrigen.split(',')

numArtistas = 1
if (len( lineaOrigen[2].split(';') ) > 0 ):
  numArtistas = len( lineaOrigen[2].split(';') ) 

explicito = lineaOrigen[7]
if(explicito[0] == 'T'):
    explicito = -1
elif(explicito[0] == 'F'):
    explicito = 1
else:
  explicito = 0

tempo = float(lineaOrigen[-3])
if(tempo == 128):
  tempo = 10
elif(tempo > 120):
  tempo = 1
elif(tempo <= 120 and tempo > 100):
  tempo = 0
elif(tempo <= 100):
  tempo = -1

popularidad = int(lineaOrigen[5]) / 100

duracion = int(lineaOrigen[6]) / (60 * 1000) 

polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

genero = lineaOrigen[-1]

lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]
print(lineaDestino)
# Out:
# 0,5SuOikwiRyPMVoIQDJUgSV,Gen Hoshino,Comedy,Comedy,73,230666,False,0.676,0.461,1,-6.746,0,0.143,0.0322,1.01e-06,0.358,0.715,128,4,acousti
# [1, 0.73, 3.8444333333333334, 1, -1.975666666666667, 10, 'acousti']

# %% [markdown]
# ### Paso 2
# Fijémonos en la Documentación Oficial de la Librería CSV (https://docs.python.org/3/library/csv.html) para este paso.
#
# PD: Como son demasiadas líneas y tarda un rato, puedes parar tú mismo la ejecución cuando veas oportuno.

# %%
import csv
with open('dataset.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
    next(spamreader) #Tema cursores, ficheros y cabecera CSV...
    for lineaOrigen in spamreader:
        print('Linea Origen:', lineaOrigen)
# Out:
# Linea Origen: ['0', '5SuOikwiRyPMVoIQDJUgSV', 'Gen Hoshino', 'Comedy', 'Comedy', '73', '230666', 'False', '0.676', '0.461', '1', '-6.746', '0', '0.143', '0.0322', '1.01e-06', '0.358', '0.715', '87.917', '4', 'acoustic']
# Linea Origen: ['1', '4qPNDBW1i3p13qLCt0Ki3A', 'Ben Woodward', 'Ghost (Acoustic)', 'Ghost - Acoustic', '55', '149610', 'False', '0.42', '0.166', '1', '-17.235', '1', '0.0763', '0.924', '5.56e-06', '0.101', '0.267', '77.489', '4', 'acoustic']
# Linea Origen: ['2', '1iJBSr7s7jYXzM8EGcbK5b', 'Ingrid Michaelson;ZAYN', 'To Begin Again', 'To Begin Again', '57', '210826', 'False', '0.438', '0.359', '0', '-9.734', '1', '0.0557', '0.21', '0.0', '0.117', '0.12', '76.332', '4', 'acoustic']
# Linea Origen: ['3', '6lfxq3CG4xtTiEg7opyCyx', 'Kina Grannis', 'Crazy Rich Asians (Original Motion Picture Soundtrack)', "Can't Help Falling In Love", '71', '201933', 'False', '0.266', '0.0596', '0', '-18.515', '1', '0.0363', '0.905', '7.07e-05', '0.132', '0.143', '181.74', '3', 'acoustic']
# Linea Origen: ['4', '5vjLSffimiIP26QG5WcN2K', 'Chord Overstreet', 'Hold On', 'Hold On', '82', '198853', 'False', '0.618', '0.443', '2', '-9.681', '1', '0.0526', '0.469', '0.0', '0.0829', '0.167', '119.949', '4', 'acoustic']
# Linea Origen: ['5', '01MVOl9KtVTNfFiBU9I7dc', 'Tyrone Wells', 'Days I Will Remember', 'Days I Will Remember', '58', '214240', 'False', '0.688', '0.481', '6', '-8.807', '1', '0.105', '0.289', '0.0', '0.189', '0.666', '98.017', '4', 'acoustic']
# Linea Origen: ['6', '6Vc5wAMmXdKIAM7WUoEb7N', 'A Great Big World;Christina Aguilera', 'Is There Anybody Out There?', 'Say Something', '74', '229400', 'False', '0.407', '0.147', '2', '-8.822', '1', '0.0355', '0.857', '2.89e-06', '0.0913', '0.0765', '141.284', '3', 'acoustic']
# Linea Origen: ['7', '1EzrEOXmMH3G43AXT1y7pA', 'Jason Mraz', 'We Sing. We Dance. We Steal Things.', "I'm Yours", '80', '242946', 'False', '0.703', '0.444', '11', '-9.331', '1', '0.0417', '0.559', '0.0', '0.0973', '0.712', '150.96', '4', 'acoustic']
# Linea Origen: ['8', '0IktbUcnAGrvD03AWnz3Q8', 'Jason Mraz;Colbie Caillat', 'We Sing. We Dance. We Steal Things.', 'Lucky', '74', '189613', 'False', '0.625', '0.414', '0', '-8.7', '1', '0.0369', '0.294', '0.0', '0.151', '0.669', '130.088', '4', 'acoustic']
# Linea Origen: ['4017', '0O0bttAxJKKWqAqY2Nq4mC', 'Cigarettes After Sex', 'Cry', 'Falling In Love', '68', '245840', 'False', '0.472', '0.27', '7', '-11.649', '1', '0.027', '0.729', '0.0158', '0.125', '0.373', '140.673', '4', 'ambient']
# Linea Origen: ['4018', '4nvLuqwTOZdEJI1fcHXv8h', 'Cigarettes After Sex', "You're All I Want", "You're All I Want", '68', '264453', 'False', '0.233', '0.471', '5', '-10.947', '1', '0.0294', '0.363', '0.828', '0.113', '0.277', '182.161', '4', 'ambient']
# Linea Origen: ['4019', '0u4rkpmNtgcFxYHepnVF4v', 'Novo Amor', 'Bathing Beach', 'Carry You', '68', '273106', 'False', '0.334', '0.397', '7', '-7.993', '1', '0.0284', '0.558', '0.0774', '0.126', '0.035', '93.445', '4', 'ambient']
# Linea Origen: ['4020', '5DZNSYxhFA1WA9WEJg9TNY', 'Cigarettes After Sex', 'EP I.', 'Dreaming of You', '63', '322218', 'False', '0.298', '0.398', '7', '-14.911', '1', '0.0365', '0.549', '0.105', '0.136', '0.174', '64.135', '3', 'ambient']
# Linea Origen: ['4021', '7qH9Z4dJEN0l9bidizW7fq', 'Novo Amor', 'Bathing Beach', 'Anchor', '75', '257533', 'False', '0.457', '0.407', '9', '-11.475', '1', '0.0308', '0.805', '0.884', '0.126', '0.126', '117.053', '4', 'ambient']
# Linea Origen: ['4022', '2hIsd0F6ZGfHCC1xa7vSad', 'Cigarettes After Sex', 'Cigarettes After Sex', 'Each Time You Fall in Love', '65', '290630', 'False', '0.378', '0.533', '10', '-8.843', '1', '0.0279', '0.479', '0.508', '0.131', '0.285', '75.927', '4', 'ambient']
# Linea Origen: ['4023', '5Bv3hddlRFyhTcYtYeoXed', 'Mohan', 'Udaan', 'Naav (Chadhti Lehrein Laang Na Paye)', '43', '252158', 'False', '0.608', '0.687', '2', '-7.083', '1', '0.0536', '0.449', '2.1e-06', '0.0625', '0.548', '83.918', '4', 'ambient']
# Linea Origen: ['4024', '3YL4zMqcyFu0OfLI1sZ66Z', 'Cigarettes After Sex', 'EP I.', 'Starry Eyes', '62', '206000', 'False', '0.419', '0.362', '2', '-15.32', '1', '0.0337', '0.453', '0.335', '0.0687', '0.114', '100.264', '4', 'ambient']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-02ec5bf3897b> in <module>
#       4     next(spamreader) #Tema cursores, ficheros y cabecera CSV...
#       5     for lineaOrigen in spamreader:
# ----> 6         print('Linea Origen:', lineaOrigen)
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.8/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.8/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Paso 3
#
# Ahora toca unir el paso 1 y 2. ¿Se te ocurre cómo?
#
# > **Ejercicio**: Completa este paso tú mismo.

# %%
# <SOL>
import csv
with open('dataset.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
    next(spamreader) #Tema cursores, ficheros y cabecera CSV...
    for lineaOrigen in spamreader:
    #Pego el código que me interesa...
      numArtistas = 1
      if (len( lineaOrigen[2].split(';') ) > 0 ):
        numArtistas = len( lineaOrigen[2].split(';') ) 

      explicito = lineaOrigen[7]
      if(explicito[0] == 'T'):
          explicito = -1
      elif(explicito[0] == 'F'):
          explicito = 1
      else:
        explicito = 0

      tempo = float(lineaOrigen[-3])
      if(tempo == 128):
        tempo = 10
      elif(tempo > 120):
        tempo = 1
      elif(tempo <= 120 and tempo > 100):
        tempo = 0
      elif(tempo <= 100):
        tempo = -1

      popularidad = int(lineaOrigen[5]) / 100

      duracion = int(lineaOrigen[6]) / (60 * 1000) 

      polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

      genero = lineaOrigen[-1]

      lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]

      print('Linea Destino:', lineaDestino)

#</SOL>
# Out:
# Streaming output truncated to the last 5000 lines.
# Linea Destino: [1, 0.65, 4.57075, 1, -1.7166666666666668, 1, 'acoustic']
# Linea Destino: [1, 0.6, 2.834, 1, -1.6535, 0, 'acoustic']
# Linea Destino: [1, 0.54, 4.46275, 1, -2.9952, -1, 'acoustic']
# Linea Destino: [1, 0.37, 4.1691, 1, -3.7282999999999995, 0, 'acoustic']
# Linea Destino: [1, 0.34, 4.841333333333333, 1, -1.7199, 0, 'acoustic']
# Linea Destino: [1, 0.55, 3.3036333333333334, 1, -3.1272, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.756666666666667, 1, -4.044066666666667, 1, 'acoustic']
# Linea Destino: [1, 0.48, 4.331283333333333, 1, -2.1513666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.34, 4.8071, 1, -1.8087333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.65605, 1, -3.5611333333333337, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.4737666666666667, 1, -1.9896333333333331, -1, 'acoustic']
# Linea Destino: [1, 0.32, 4.724666666666667, 1, -3.013633333333333, -1, 'acoustic']
# Linea Destino: [1, 0.54, 3.426433333333333, 1, -3.8143000000000007, 1, 'acoustic']
# Linea Destino: [2, 0.61, 5.07155, 1, -3.1389, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.9928833333333333, 1, -2.3442000000000003, 0, 'acoustic']
# Linea Destino: [1, 0.55, 3.7854666666666668, 1, -2.5513666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.34, 4.0511, 1, -1.3124666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.33, 6.153333333333333, 1, -3.6159999999999997, -1, 'acoustic']
# Linea Destino: [2, 0.45, 1.2848833333333334, 1, -6.111900000000001, 1, 'acoustic']
# Linea Destino: [1, 0.33, 4.080666666666667, 1, -1.5149000000000001, 0, 'acoustic']
# Linea Destino: [1, 0.34, 4.587766666666667, 1, -1.5826666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.34, 5.512, 1, -1.685833333333333, 0, 'acoustic']
# Linea Destino: [1, 0.49, 2.732666666666667, 1, -3.5431666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.33, 3.2312333333333334, 1, -2.623133333333333, -1, 'acoustic']
# Linea Destino: [1, 0.62, 3.5622, 1, -2.357466666666667, -1, 'acoustic']
# Linea Destino: [1, 0.33, 3.7842166666666666, 1, -1.774733333333333, 1, 'acoustic']
# Linea Destino: [1, 0.31, 3.5906666666666665, 1, -2.3979666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.32, 2.275716666666667, 1, -2.1257, 1, 'acoustic']
# Linea Destino: [1, 0.32, 3.72845, -1, -1.7719000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.13635, 1, -2.8333333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.5, 2.8626666666666667, 1, -3.9020999999999995, 0, 'acoustic']
# Linea Destino: [1, 0.58, 5.10405, 1, -6.479966666666666, 1, 'acoustic']
# Linea Destino: [1, 0.49, 3.2064833333333334, 1, -3.3906666666666667, -1, 'acoustic']
# Linea Destino: [2, 0.52, 3.6412, 1, -3.1862999999999997, 1, 'acoustic']
# Linea Destino: [1, 0.49, 2.963633333333333, 1, -3.875033333333333, 0, 'acoustic']
# Linea Destino: [1, 0.53, 4.187766666666667, 1, -0.6433000000000001, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.99, 1, -3.621166666666667, 0, 'acoustic']
# Linea Destino: [2, 0.5, 4.02355, 1, -3.154, -1, 'acoustic']
# Linea Destino: [1, 0.57, 3.6133333333333333, 1, -2.7428666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.53, 2.6884333333333332, 1, -3.5778, 0, 'acoustic']
# Linea Destino: [1, 0.57, 2.55175, 1, -5.074933333333333, -1, 'acoustic']
# Linea Destino: [1, 0.49, 3.36945, 1, -3.5572, 0, 'acoustic']
# Linea Destino: [1, 0.52, 2.890433333333333, 1, -4.453133333333333, -1, 'acoustic']
# Linea Destino: [1, 0.51, 2.4107333333333334, 1, -4.670266666666667, 0, 'acoustic']
# Linea Destino: [1, 0.46, 3.546, 1, -4.9690666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.41, 4.0293, 1, -4.686633333333333, 1, 'acoustic']
# Linea Destino: [1, 0.57, 2.8266666666666667, 1, -3.5020000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.5, 5.110433333333333, 1, -0.8414666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.42, 3.5744333333333334, 1, -5.516366666666666, 1, 'acoustic']
# Linea Destino: [1, 0.47, 2.6744333333333334, 1, -2.2564666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.55, 2.9804333333333335, 1, -1.708466666666667, 1, 'acoustic']
# Linea Destino: [1, 0.56, 2.3084333333333333, 1, -3.7423, 1, 'acoustic']
# Linea Destino: [1, 0.49, 3.84355, 1, -1.5504333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.5, 1.8640333333333334, 1, -3.8461, -1, 'acoustic']
# Linea Destino: [1, 0.56, 3.05355, 1, -3.105633333333333, 0, 'acoustic']
# Linea Destino: [1, 0.52, 3.675116666666667, 1, -3.2942000000000005, -1, 'acoustic']
# Linea Destino: [1, 0.5, 4.141766666666666, 1, -2.857566666666667, 1, 'acoustic']
# Linea Destino: [1, 0.53, 4.499766666666667, 1, -5.3795, -1, 'acoustic']
# Linea Destino: [1, 0.33, 4.546216666666667, 1, -3.7913666666666668, -1, 'acoustic']
# Linea Destino: [2, 0.54, 3.1607666666666665, 1, -3.0336, 1, 'acoustic']
# Linea Destino: [2, 0.5, 4.380333333333334, 1, -2.1031666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.54, 3.25355, 1, -1.2412666666666665, 0, 'acoustic']
# Linea Destino: [1, 0.55, 3.8051833333333334, 1, -1.9943333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.32, 2.5965333333333334, 1, -2.973966666666666, -1, 'acoustic']
# Linea Destino: [1, 0.33, 4.2751, 1, -1.8669000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.5, 4.0, 1, -2.1421, 1, 'acoustic']
# Linea Destino: [1, 0.56, 3.2222166666666667, 1, -4.679433333333333, 0, 'acoustic']
# Linea Destino: [1, 0.63, 4.5511, 1, -2.686566666666667, 1, 'acoustic']
# Linea Destino: [1, 0.48, 2.70515, 1, -4.2763333333333335, 0, 'acoustic']
# Linea Destino: [1, 0.54, 3.168433333333333, 1, -6.965166666666666, 1, 'acoustic']
# Linea Destino: [2, 0.31, 5.322, 1, -1.4768666666666663, 1, 'acoustic']
# Linea Destino: [1, 0.31, 3.95155, 1, -1.9561333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.6, 3.926433333333333, 1, -2.8896666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.67, 3.864, 1, -1.4202666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.33, 2.7277666666666667, 1, -2.2968666666666664, 1, 'acoustic']
# Linea Destino: [2, 0.32, 2.0337666666666667, -1, -2.3729999999999998, 1, 'acoustic']
# Linea Destino: [1, 0.31, 2.763316666666667, 1, -2.5629666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.0, 2.677766666666667, 1, -3.776733333333334, 0, 'acoustic']
# Linea Destino: [1, 0.31, 3.260666666666667, 1, -1.5380666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.45, 4.238266666666667, 1, -3.9194999999999993, 1, 'acoustic']
# Linea Destino: [1, 0.56, 4.272683333333333, 1, -6.614333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.45, 4.954433333333333, 1, -3.7802333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.42, 2.8354166666666667, 1, -5.264733333333333, 1, 'acoustic']
# Linea Destino: [1, 0.46, 4.550433333333333, 1, -3.183, 0, 'acoustic']
# Linea Destino: [1, 0.5, 3.0471, 1, -1.6291666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.45, 3.6228833333333332, 1, -2.3393333333333337, 1, 'acoustic']
# Linea Destino: [1, 0.56, 3.468366666666667, 1, -4.138166666666667, 1, 'acoustic']
# Linea Destino: [1, 0.43, 4.018666666666666, 1, -4.995433333333334, 1, 'acoustic']
# Linea Destino: [1, 0.39, 3.9166666666666665, 1, -2.7627333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.53, 2.8794333333333335, 1, -4.249933333333333, 1, 'acoustic']
# Linea Destino: [1, 0.45, 3.9975833333333335, 1, -2.947366666666667, 0, 'acoustic']
# Linea Destino: [1, 0.32, 4.08, 1, -2.4903000000000004, -1, 'acoustic']
# Linea Destino: [1, 0.53, 2.3547666666666665, 1, -3.993133333333333, 1, 'acoustic']
# Linea Destino: [1, 0.54, 2.4252333333333334, 1, -4.011233333333333, 0, 'acoustic']
# Linea Destino: [1, 0.51, 3.7231, 1, -3.5493, -1, 'acoustic']
# Linea Destino: [2, 0.55, 2.2757, 1, -5.070233333333333, 0, 'acoustic']
# Linea Destino: [2, 0.33, 3.5226333333333333, 1, -5.2521, 0, 'acoustic']
# Linea Destino: [1, 0.55, 1.2742166666666668, 1, -6.227666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.46, 4.5521, 1, -3.824633333333334, 1, 'acoustic']
# Linea Destino: [1, 0.3, 4.478933333333333, 1, -4.321166666666667, 1, 'acoustic']
# Linea Destino: [1, 0.46, 3.4276333333333335, 1, -2.2512666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.6, 4.278, 1, -3.955533333333333, 1, 'acoustic']
# Linea Destino: [1, 0.51, 4.4231, 1, -2.377266666666667, 1, 'acoustic']
# Linea Destino: [1, 0.47, 3.6551, 1, -3.2475666666666663, -1, 'acoustic']
# Linea Destino: [1, 0.6, 2.37, 1, -3.9329, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.6468833333333333, 1, -1.6608999999999998, -1, 'acoustic']
# Linea Destino: [3, 0.6, 3.7041666666666666, 1, -2.7882666666666664, -1, 'acoustic']
# Linea Destino: [1, 0.52, 1.9626666666666666, 1, -4.877833333333333, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.3466666666666667, 1, -3.8582333333333327, -1, 'acoustic']
# Linea Destino: [1, 0.52, 3.084216666666667, 1, -3.5432666666666672, 0, 'acoustic']
# Linea Destino: [1, 0.51, 1.0068833333333334, 1, -3.201866666666667, -1, 'acoustic']
# Linea Destino: [1, 0.3, 4.080216666666667, 1, -2.1595, 0, 'acoustic']
# Linea Destino: [1, 0.3, 2.828883333333333, 1, -2.2557666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.62, 3.14, 1, -5.219, 1, 'acoustic']
# Linea Destino: [1, 0.64, 4.574666666666666, 1, -2.347566666666667, 1, 'acoustic']
# Linea Destino: [2, 0.57, 4.587766666666667, 1, -4.2842, -1, 'acoustic']
# Linea Destino: [1, 0.31, 2.0733333333333333, 1, -3.7273666666666663, 0, 'acoustic']
# Linea Destino: [1, 0.71, 2.4284333333333334, 1, -2.685333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.31, 4.4199166666666665, -1, -3.2201, 1, 'acoustic']
# Linea Destino: [2, 0.3, 3.9287, 1, -1.7199666666666669, 1, 'acoustic']
# Linea Destino: [1, 0.3, 3.1492, -1, -1.6931666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.3, 4.020833333333333, 1, -1.2494666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.3, 2.4354833333333334, -1, -1.5146333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.3, 2.68675, -1, -2.0656333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.59, 3.586883333333333, 1, -1.5553666666666668, 1, 'acoustic']
# Linea Destino: [1, 0.3, 3.2802166666666666, 1, -1.1366666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.3, 3.0702833333333333, -1, -2.0530666666666666, 0, 'acoustic']
# Linea Destino: [2, 0.63, 3.834966666666667, 1, -2.0113333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.3, 2.1578666666666666, 1, -2.6810333333333336, 1, 'acoustic']
# Linea Destino: [1, 0.44, 4.162133333333333, 1, -4.1962, -1, 'acoustic']
# Linea Destino: [2, 0.54, 3.5509166666666667, 1, -2.3678333333333335, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.8095166666666667, 1, -3.5235, -1, 'acoustic']
# Linea Destino: [1, 0.47, 3.3703166666666666, 1, -2.4804666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.41, 4.039116666666667, 1, -4.7335, 1, 'acoustic']
# Linea Destino: [1, 0.43, 3.145583333333333, 1, -3.5887333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.65, 4.277466666666666, 1, -2.821766666666667, 0, 'acoustic']
# Linea Destino: [1, 0.53, 2.9112833333333334, 1, -4.938033333333334, 1, 'acoustic']
# Linea Destino: [1, 0.47, 3.49305, 1, -4.240833333333334, -1, 'acoustic']
# Linea Destino: [1, 0.55, 2.7413, 1, -2.903966666666667, -1, 'acoustic']
# Linea Destino: [1, 0.45, 2.30335, 1, -2.658633333333333, -1, 'acoustic']
# Linea Destino: [1, 0.69, 4.067783333333334, 1, -1.6895, 0, 'acoustic']
# Linea Destino: [1, 0.37, 3.300666666666667, 1, -2.7679000000000005, 0, 'acoustic']
# Linea Destino: [1, 0.34, 4.434633333333333, 1, -3.0004000000000004, 0, 'acoustic']
# Linea Destino: [1, 0.53, 4.861266666666666, 1, -3.2058, 1, 'acoustic']
# Linea Destino: [1, 0.31, 6.379766666666667, 1, -1.7756999999999998, 1, 'acoustic']
# Linea Destino: [1, 0.31, 5.381766666666667, 1, -1.8338000000000003, -1, 'acoustic']
# Linea Destino: [1, 0.47, 4.066316666666666, 1, -4.034066666666667, 1, 'acoustic']
# Linea Destino: [1, 0.45, 4.3825666666666665, 1, -3.7361333333333335, 0, 'acoustic']
# Linea Destino: [1, 0.51, 2.8007, 1, -4.7464666666666675, 1, 'acoustic']
# Linea Destino: [1, 0.51, 2.1966666666666668, 1, -3.982433333333333, 0, 'acoustic']
# Linea Destino: [1, 0.31, 5.443333333333333, 1, -1.5075666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.48, 2.772, 1, -5.067266666666667, 1, 'acoustic']
# Linea Destino: [1, 0.48, 2.971983333333333, 1, -2.9532333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.51, 4.156433333333333, 1, -3.2754, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.3482166666666666, 1, -2.1741333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.32, 4.874883333333333, 1, -0.9030999999999999, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.161216666666667, 1, -4.6518, -1, 'acoustic']
# Linea Destino: [1, 0.6, 4.274, 1, -1.2985, -1, 'acoustic']
# Linea Destino: [2, 0.47, 2.4634833333333335, 1, -4.520466666666667, 0, 'acoustic']
# Linea Destino: [2, 0.29, 4.110733333333333, 1, -2.9410666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.8071, 1, -5.188566666666667, 1, 'acoustic']
# Linea Destino: [1, 0.41, 3.4566666666666666, 1, -4.2494, -1, 'acoustic']
# Linea Destino: [1, 0.48, 3.1392333333333333, 1, -3.658266666666666, 0, 'acoustic']
# Linea Destino: [1, 0.61, 2.8118666666666665, 1, -2.5545, 1, 'acoustic']
# Linea Destino: [1, 0.6, 3.1366666666666667, 1, -2.943000000000001, 0, 'acoustic']
# Linea Destino: [1, 0.45, 3.0249333333333333, 1, -3.5858333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.58, 4.670433333333333, 1, -2.455666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.29, 4.238433333333333, 1, -2.0766, 1, 'acoustic']
# Linea Destino: [1, 0.57, 4.602433333333333, 1, -3.0347666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.29, 4.578666666666667, 1, -2.9065666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.49, 2.663666666666667, 1, -3.9467, 0, 'acoustic']
# Linea Destino: [1, 0.3, 2.9762166666666667, 1, -2.4848, 0, 'acoustic']
# Linea Destino: [1, 0.3, 2.9174333333333333, -1, -3.4157333333333337, -1, 'acoustic']
# Linea Destino: [1, 0.31, 3.01285, 1, -2.323933333333333, 0, 'acoustic']
# Linea Destino: [1, 0.29, 3.1842, 1, -1.7744666666666664, 0, 'acoustic']
# Linea Destino: [1, 0.59, 3.5777666666666668, 1, -2.7754333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.3, 2.7911, -1, -2.6128666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.3, 4.212666666666666, -1, -2.5436, -1, 'acoustic']
# Linea Destino: [1, 0.29, 2.28025, -1, -1.8153333333333332, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.1818166666666667, -1, -4.225233333333333, 1, 'acoustic']
# Linea Destino: [1, 0.49, 3.63555, 1, -3.296, -1, 'acoustic']
# Linea Destino: [1, 0.5, 3.0182166666666665, 1, -2.5322999999999998, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.5417666666666667, 1, -0.7731, -1, 'acoustic']
# Linea Destino: [1, 0.49, 2.874233333333333, 1, -4.592099999999999, 1, 'acoustic']
# Linea Destino: [1, 0.32, 3.9007666666666667, 1, -2.737866666666666, 1, 'acoustic']
# Linea Destino: [1, 0.53, 5.503333333333333, 1, -2.6074, 1, 'acoustic']
# Linea Destino: [1, 0.46, 3.1830166666666666, 1, -3.071366666666666, 1, 'acoustic']
# Linea Destino: [1, 0.23, 4.007483333333333, 1, -1.627533333333333, 1, 'acoustic']
# Linea Destino: [1, 0.41, 1.4878, 1, -4.196666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.49, 3.55755, 1, -2.6654, 1, 'acoustic']
# Linea Destino: [1, 0.59, 3.918433333333333, 1, -2.789966666666667, 1, 'acoustic']
# Linea Destino: [1, 0.43, 3.6662666666666666, 1, -3.2245666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.31, 4.324883333333333, 1, -2.3676, -1, 'acoustic']
# Linea Destino: [1, 0.46, 3.7008666666666667, 1, -3.5066666666666673, 1, 'acoustic']
# Linea Destino: [1, 0.5, 2.4762166666666667, 1, -6.2116999999999996, 0, 'acoustic']
# Linea Destino: [1, 0.41, 4.081666666666667, 1, -5.0864, -1, 'acoustic']
# Linea Destino: [2, 0.48, 3.875, 1, -2.0520333333333336, 0, 'acoustic']
# Linea Destino: [2, 0.36, 3.2589166666666665, 1, -6.170933333333334, 1, 'acoustic']
# Linea Destino: [1, 0.44, 4.264883333333334, 1, -1.0836, 1, 'acoustic']
# Linea Destino: [1, 0.56, 2.48355, 1, -4.755966666666667, -1, 'acoustic']
# Linea Destino: [1, 0.29, 3.46555, 1, -1.663433333333333, -1, 'acoustic']
# Linea Destino: [1, 0.52, 3.9788833333333335, 1, -2.8373000000000004, -1, 'acoustic']
# Linea Destino: [1, 0.31, 3.94755, 1, -0.8659666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.47, 3.045733333333333, 1, -3.273933333333334, -1, 'acoustic']
# Linea Destino: [1, 0.56, 5.125566666666667, 1, -3.3837333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.37, 1.35, 1, -3.5483333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.24, 2.4286666666666665, 1, -2.6869333333333336, 1, 'acoustic']
# Linea Destino: [1, 0.23, 3.473333333333333, 1, -1.2777333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.796, 1, -2.6633333333333336, -1, 'acoustic']
# Linea Destino: [2, 0.51, 4.061333333333334, 1, -2.5172, 1, 'acoustic']
# Linea Destino: [1, 0.51, 3.93965, 1, -3.1712000000000002, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.61555, 1, -2.781633333333333, -1, 'acoustic']
# Linea Destino: [1, 0.5, 4.41955, 1, -3.4154, 1, 'acoustic']
# Linea Destino: [1, 0.31, 4.096666666666667, 1, -2.485066666666667, 0, 'acoustic']
# Linea Destino: [1, 0.3, 5.967333333333333, 1, -1.7427, 1, 'acoustic']
# Linea Destino: [1, 0.31, 4.675766666666667, 1, -1.4045000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.29, 3.8485833333333335, 1, -3.398966666666667, 0, 'acoustic']
# Linea Destino: [1, 0.61, 4.5772, 1, -3.6449000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.075466666666666, 1, -3.057533333333333, 0, 'acoustic']
# Linea Destino: [3, 0.55, 2.298, 1, -2.7988666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.29, 2.535, 1, -5.153766666666667, 1, 'acoustic']
# Linea Destino: [1, 0.3, 2.7047, -1, -1.0042666666666669, 1, 'acoustic']
# Linea Destino: [1, 0.29, 4.261333333333333, 1, -1.7802333333333331, 1, 'acoustic']
# Linea Destino: [1, 0.3, 3.6149, -1, -2.903866666666667, 0, 'acoustic']
# Linea Destino: [1, 0.29, 3.9833333333333334, 1, -3.2284666666666673, 0, 'acoustic']
# Linea Destino: [1, 0.29, 2.1455166666666665, 1, -0.5630333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.3, 6.365166666666667, 1, -0.9039999999999999, -1, 'acoustic']
# Linea Destino: [1, 0.29, 3.26935, -1, -3.065566666666666, -1, 'acoustic']
# Linea Destino: [1, 0.28, 2.6088833333333334, 1, -1.6476666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.42, 2.5841666666666665, 1, -4.575033333333333, 1, 'acoustic']
# Linea Destino: [2, 0.49, 2.0946166666666666, 1, -4.334266666666667, -1, 'acoustic']
# Linea Destino: [2, 0.53, 2.817633333333333, 1, -2.0706666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.5, 3.2787333333333333, 1, -3.490166666666667, 1, 'acoustic']
# Linea Destino: [1, 0.52, 3.318566666666667, 1, -4.245500000000001, 1, 'acoustic']
# Linea Destino: [1, 0.36, 2.6153833333333334, 1, -2.467733333333333, 1, 'acoustic']
# Linea Destino: [1, 0.49, 4.2435833333333335, 1, -4.448966666666666, 1, 'acoustic']
# Linea Destino: [1, 0.4, 3.7031, 1, -5.884766666666667, 1, 'acoustic']
# Linea Destino: [1, 0.51, 3.9383, 1, -2.9645666666666664, 0, 'acoustic']
# Linea Destino: [1, 0.41, 3.3837333333333333, 1, -1.8680333333333332, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.8002166666666666, 1, -7.7062, -1, 'acoustic']
# Linea Destino: [1, 0.52, 3.7745, 1, -1.1916666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.51, 3.0266, 1, -3.9599333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.49, 3.2105166666666665, 1, -3.396233333333333, 0, 'acoustic']
# Linea Destino: [1, 0.54, 5.314, 1, -3.435366666666667, 1, 'acoustic']
# Linea Destino: [1, 0.46, 4.464366666666667, 1, -3.512966666666667, 1, 'acoustic']
# Linea Destino: [1, 0.45, 2.9147333333333334, 1, -3.191266666666666, 0, 'acoustic']
# Linea Destino: [1, 0.3, 5.786666666666667, 1, -1.8423666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.53, 3.7683, 1, -1.422, -1, 'acoustic']
# Linea Destino: [1, 0.48, 4.702216666666667, 1, -1.3416666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.52, 4.194, 1, -1.3999333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.51, 4.971333333333333, 1, -2.502066666666667, 1, 'acoustic']
# Linea Destino: [1, 0.59, 4.025766666666667, 1, -4.1214, 1, 'acoustic']
# Linea Destino: [1, 0.53, 3.2861666666666665, 1, -3.8623666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.47, 2.9682166666666667, 1, -0.9585, 0, 'acoustic']
# Linea Destino: [1, 0.28, 3.842416666666667, 1, -2.8155000000000006, 1, 'acoustic']
# Linea Destino: [1, 0.3, 2.7302166666666667, 1, -2.314766666666667, 0, 'acoustic']
# Linea Destino: [1, 0.29, 3.534666666666667, 1, -1.8579999999999999, 1, 'acoustic']
# Linea Destino: [1, 0.48, 2.6128833333333334, 1, -3.071566666666667, -1, 'acoustic']
# Linea Destino: [1, 0.52, 2.8581, 1, -2.903933333333333, -1, 'acoustic']
# Linea Destino: [1, 0.28, 5.202216666666667, 1, -4.5465333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.51, 4.139766666666667, 1, -3.7190333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.53, 4.856433333333333, 1, -3.2454000000000005, -1, 'acoustic']
# Linea Destino: [1, 0.52, 4.233766666666667, 1, -3.0704, 0, 'acoustic']
# Linea Destino: [1, 0.42, 3.933333333333333, 1, -3.4834, -1, 'acoustic']
# Linea Destino: [1, 0.29, 2.2306666666666666, 1, -1.3185, 1, 'acoustic']
# Linea Destino: [1, 0.29, 3.82555, 1, -2.3179, 1, 'acoustic']
# Linea Destino: [1, 0.6, 4.6562166666666664, 1, -1.7335333333333336, -1, 'acoustic']
# Linea Destino: [1, 0.51, 1.0051, 1, -4.8936, 0, 'acoustic']
# Linea Destino: [2, 0.28, 2.0790333333333333, 1, -2.181966666666667, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.816666666666667, 1, -1.2962000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.28, 3.2702166666666668, 1, -1.1117333333333332, 1, 'acoustic']
# Linea Destino: [1, 0.58, 2.833283333333333, 1, -3.490066666666667, -1, 'acoustic']
# Linea Destino: [3, 0.54, 2.012, 1, -4.0769, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.4879, 1, -2.030133333333333, 0, 'acoustic']
# Linea Destino: [1, 0.29, 2.1172166666666667, -1, -3.1949, -1, 'acoustic']
# Linea Destino: [2, 0.28, 2.8234, 1, -1.7733666666666668, 0, 'acoustic']
# Linea Destino: [1, 0.28, 3.3765666666666667, 1, -0.8240333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.28, 2.085, -1, -3.197266666666667, -1, 'acoustic']
# Linea Destino: [1, 0.28, 3.3733333333333335, 1, -1.3862333333333332, 1, 'acoustic']
# Linea Destino: [1, 0.52, 6.768383333333333, 1, -5.280499999999999, 1, 'acoustic']
# Linea Destino: [1, 0.46, 4.130083333333333, 1, -1.8386333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.47, 3.196083333333333, 1, -3.4354333333333336, 1, 'acoustic']
# Linea Destino: [1, 0.39, 3.2066166666666667, 1, -5.246300000000001, -1, 'acoustic']
# Linea Destino: [1, 0.5, 2.578866666666667, 1, -4.6459, 1, 'acoustic']
# Linea Destino: [1, 0.43, 3.5957666666666666, 1, -2.3306999999999998, 1, 'acoustic']
# Linea Destino: [2, 0.3, 3.6431666666666667, 1, -6.342633333333333, 0, 'acoustic']
# Linea Destino: [1, 0.53, 4.199333333333334, 1, -2.3657, 0, 'acoustic']
# Linea Destino: [1, 0.51, 2.7537166666666666, 1, -2.7623666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.31, 3.80645, 1, -2.160633333333333, -1, 'acoustic']
# Linea Destino: [1, 0.29, 4.538666666666667, 1, -1.7279, -1, 'acoustic']
# Linea Destino: [1, 0.43, 3.9326666666666665, 1, -5.684966666666667, 0, 'acoustic']
# Linea Destino: [1, 0.55, 3.2354833333333333, 1, -2.7084666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.5, 3.7588833333333334, 1, -1.3478333333333337, 1, 'acoustic']
# Linea Destino: [1, 0.3, 5.440216666666666, 1, -1.3847333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.46, 3.4704333333333333, 1, -2.2758333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.46, 2.466666666666667, 1, -2.9529666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.52, 4.334, 1, -1.8846999999999998, 1, 'acoustic']
# Linea Destino: [2, 0.44, 1.6923166666666667, 1, -3.455, 1, 'acoustic']
# Linea Destino: [1, 0.51, 2.9777666666666667, 1, -4.256566666666667, -1, 'acoustic']
# Linea Destino: [1, 0.53, 3.9466666666666668, 1, -2.1176333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.47, 2.4904333333333333, 1, -3.2426999999999997, 1, 'acoustic']
# Linea Destino: [1, 0.48, 2.4687833333333336, 1, -4.380533333333333, 1, 'acoustic']
# Linea Destino: [1, 0.56, 3.6902166666666667, 1, -1.7223333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.48, 3.1791833333333335, 1, -2.5737666666666663, -1, 'acoustic']
# Linea Destino: [1, 0.47, 3.91, 1, -1.5970666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.29, 5.5004333333333335, 1, -2.019066666666667, 0, 'acoustic']
# Linea Destino: [1, 0.28, 3.0244333333333335, 1, -1.7345666666666668, 1, 'acoustic']
# Linea Destino: [1, 0.28, 3.624433333333333, 1, -1.6312666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.67, 2.8728833333333332, 1, -2.3253, 0, 'acoustic']
# Linea Destino: [1, 0.29, 4.651133333333333, 1, -3.417966666666667, -1, 'acoustic']
# Linea Destino: [3, 0.56, 2.4393333333333334, 1, -1.779, 0, 'acoustic']
# Linea Destino: [1, 0.54, 4.222216666666666, 1, -3.4809, 0, 'acoustic']
# Linea Destino: [1, 0.25, 3.933333333333333, 1, -3.8785666666666665, 0, 'acoustic']
# Linea Destino: [1, 0.49, 3.7804333333333333, 1, -1.3715000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.48565, 1, -3.429866666666667, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.802216666666666, 1, -2.0402, 1, 'acoustic']
# Linea Destino: [1, 0.29, 3.576, 1, -1.6389000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.53, 1.6311, 1, -1.5006333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.28, 1.5744333333333334, 1, -3.0069, 1, 'acoustic']
# Linea Destino: [1, 0.28, 2.46725, 1, -3.477066666666667, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.064, 1, -1.1596, 1, 'acoustic']
# Linea Destino: [1, 0.28, 3.4154333333333335, 1, -0.6606666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.8019666666666665, 1, -0.969, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.907766666666667, -1, -1.604, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.535, -1, -0.8546333333333332, 1, 'acoustic']
# Linea Destino: [2, 0.29, 2.6166666666666667, 1, -2.8187333333333338, -1, 'acoustic']
# Linea Destino: [1, 0.0, 3.60155, 1, -1.7577999999999998, -1, 'acoustic']
# Linea Destino: [1, 0.0, 3.60155, 1, -1.7577999999999998, -1, 'acoustic']
# Linea Destino: [1, 0.0, 3.6702166666666667, 1, -3.0430333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.32, 4.095433333333333, 1, -1.8043666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.35, 2.88095, -1, -3.2951333333333337, -1, 'acoustic']
# Linea Destino: [1, 0.49, 2.5984, 1, -2.3763333333333336, -1, 'acoustic']
# Linea Destino: [1, 0.52, 2.92, 1, -2.1563666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.31, 3.4731, 1, -2.1678333333333337, 1, 'acoustic']
# Linea Destino: [2, 0.28, 4.1131, 1, -1.0802333333333332, 0, 'acoustic']
# Linea Destino: [2, 0.48, 3.660833333333333, 1, -2.6447, 1, 'acoustic']
# Linea Destino: [1, 0.48, 4.210666666666667, 1, -5.015333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.41, 3.5797333333333334, 1, -3.559066666666667, -1, 'acoustic']
# Linea Destino: [2, 0.47, 3.6006666666666667, 1, -1.5851333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.568883333333333, 1, -3.4669333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.6, 4.198883333333334, 1, -3.9568666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.47, 4.944216666666667, 1, -1.1745, 1, 'acoustic']
# Linea Destino: [1, 0.3, 3.358433333333333, 1, -2.281333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.49, 3.36435, 1, -2.7982, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.854433333333333, 1, -1.3322666666666667, -1, 'acoustic']
# Linea Destino: [2, 0.5, 3.9967, 1, -2.143166666666666, 1, 'acoustic']
# Linea Destino: [1, 0.28, 4.127766666666667, 1, -2.2219333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.51, 2.591833333333333, 1, -2.229666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.45, 2.7464333333333335, 1, -2.5817, 1, 'acoustic']
# Linea Destino: [1, 0.54, 3.0578666666666665, 1, -2.3904666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.54, 3.6417, 1, -2.904833333333334, -1, 'acoustic']
# Linea Destino: [2, 0.57, 4.486816666666667, 1, -4.266133333333333, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.048, 1, -2.4068, 1, 'acoustic']
# Linea Destino: [1, 0.57, 4.332, 1, -2.6417333333333333, -1, 'acoustic']
# Linea Destino: [4, 0.55, 5.30555, 1, -6.086100000000001, -1, 'acoustic']
# Linea Destino: [1, 0.3, 1.6333333333333333, 1, -2.5782666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.0384333333333333, 1, -2.2312, -1, 'acoustic']
# Linea Destino: [1, 0.41, 3.6606666666666667, 1, -3.1572, 0, 'acoustic']
# Linea Destino: [1, 0.28, 6.028216666666666, 1, -1.7343000000000002, -1, 'acoustic']
# Linea Destino: [1, 0.57, 3.6373333333333333, 1, -1.9707333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.8937666666666666, 1, -3.650633333333333, 0, 'acoustic']
# Linea Destino: [1, 0.27, 2.902066666666667, 1, -4.207300000000001, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.183116666666667, 1, -1.3642666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.58, 3.1547, 1, -2.2570333333333337, -1, 'acoustic']
# Linea Destino: [1, 0.27, 3.4934333333333334, -1, -1.9124666666666668, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.5493333333333332, 1, -3.1363000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.9142166666666665, 1, -2.105766666666667, -1, 'acoustic']
# Linea Destino: [1, 0.28, 2.998666666666667, 1, -2.3100666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.27, 5.5075666666666665, 1, -1.8728333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.28, 2.9174333333333333, 1, -3.507633333333333, 1, 'acoustic']
# Linea Destino: [1, 0.3, 2.5608833333333334, 1, -2.1540000000000004, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.9118166666666667, 1, -2.2898666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.28, 4.314433333333334, 1, -2.7147, 1, 'acoustic']
# Linea Destino: [1, 0.28, 2.8686833333333333, -1, -1.1521000000000001, -1, 'acoustic']
# Linea Destino: [1, 0.27, 1.9991, -1, -1.3298666666666668, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.6606666666666667, -1, -1.2617999999999998, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.08035, 1, -2.232066666666667, 0, 'acoustic']
# Linea Destino: [1, 0.28, 3.0367333333333333, -1, -3.7247999999999997, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.089766666666667, 1, -1.6831666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.65, 3.9206666666666665, 1, -1.4381000000000002, 0, 'acoustic']
# Linea Destino: [1, 0.49, 4.833333333333333, 1, -1.2562333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.52, 7.42555, 1, -2.0558333333333336, 1, 'acoustic']
# Linea Destino: [1, 0.39, 3.2312666666666665, 1, -2.0798666666666668, 0, 'acoustic']
# Linea Destino: [1, 0.38, 3.6971, 1, -2.216833333333333, 0, 'acoustic']
# Linea Destino: [1, 0.45, 5.307316666666667, 1, -1.5319666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.41, 3.998883333333333, 1, -1.1503333333333332, 1, 'acoustic']
# Linea Destino: [2, 0.49, 3.246366666666667, 1, -3.672333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.72, 1, -2.3992333333333336, -1, 'acoustic']
# Linea Destino: [1, 0.51, 3.1083833333333333, 1, -2.2893000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.35, 4.279333333333334, 1, -1.2554666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.54, 2.8772166666666665, 1, -2.6443, 1, 'acoustic']
# Linea Destino: [1, 0.48, 2.7864333333333335, 1, -8.953333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.6, 4.2585, 1, -3.7002, 1, 'acoustic']
# Linea Destino: [1, 0.57, 3.0166666666666666, 1, -3.400933333333333, 1, 'acoustic']
# Linea Destino: [1, 0.45, 4.606433333333333, 1, -3.1287333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.34, 3.274783333333333, 1, -4.780666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.4, 4.4971, 1, -3.403166666666667, 1, 'acoustic']
# Linea Destino: [1, 0.46, 3.055616666666667, 1, -5.298333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.42, 3.6316333333333333, 1, -1.8536000000000001, 1, 'acoustic']
# Linea Destino: [1, 0.36, 3.6845, 1, -2.0977333333333332, 0, 'acoustic']
# Linea Destino: [1, 0.16, 4.010666666666666, 1, -2.957366666666667, 1, 'acoustic']
# Linea Destino: [1, 0.46, 3.8253166666666667, 1, -3.3587666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.26, 2.34245, 1, -1.7849666666666668, 1, 'acoustic']
# Linea Destino: [4, 0.52, 5.28555, 1, -5.999, -1, 'acoustic']
# Linea Destino: [1, 0.26, 5.2857666666666665, 1, -3.1628000000000003, 0, 'acoustic']
# Linea Destino: [1, 0.5, 4.086, 1, -3.181133333333334, -1, 'acoustic']
# Linea Destino: [1, 0.6, 4.190666666666667, 1, -4.4004, 1, 'acoustic']
# Linea Destino: [1, 0.5, 3.1023833333333335, 1, -3.5309666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.61, 3.4582166666666665, 1, -1.1536333333333333, 0, 'acoustic']
# Linea Destino: [3, 0.26, 2.4802, 1, -3.4328333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.27, 3.318216666666667, 1, -2.5860000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.28, 3.19955, 1, -2.2745666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.846216666666667, 1, -3.8295, -1, 'acoustic']
# Linea Destino: [1, 0.45, 4.507766666666667, 1, -2.4917666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.26, 4.663016666666667, 1, -2.3741333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.28, 3.6642166666666665, 1, -1.8275, 1, 'acoustic']
# Linea Destino: [1, 0.48, 3.3313333333333333, 1, -2.8849666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.27, 1.496, 1, -2.281633333333333, 0, 'acoustic']
# Linea Destino: [1, 0.27, 3.548216666666667, 1, -1.3261, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.9382166666666665, 1, -1.8025000000000002, 1, 'acoustic']
# Linea Destino: [1, 0.28, 1.2177666666666667, -1, -1.9395999999999998, 1, 'acoustic']
# Linea Destino: [1, 0.28, 3.0875, 1, -1.6193333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.28, 2.0433333333333334, -1, -0.8560666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.29, 1.53155, 1, -2.4238, 1, 'acoustic']
# Linea Destino: [2, 0.27, 2.922266666666667, 1, -5.559766666666667, 0, 'acoustic']
# Linea Destino: [1, 0.28, 3.5683166666666666, -1, -3.002466666666667, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.650316666666667, -1, -0.932, 1, 'acoustic']
# Linea Destino: [1, 0.6, 3.4377833333333334, 1, -3.131866666666667, -1, 'acoustic']
# Linea Destino: [1, 0.28, 3.8884333333333334, 1, -1.7752, 0, 'acoustic']
# Linea Destino: [1, 0.48, 4.0244333333333335, 1, -1.6507333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.43, 3.1452, 1, -2.4322000000000004, -1, 'acoustic']
# Linea Destino: [1, 0.54, 3.8914666666666666, 1, -1.8392666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.49, 4.094216666666667, 1, -2.5296000000000003, 1, 'acoustic']
# Linea Destino: [1, 0.45, 3.306433333333333, 1, -3.133533333333333, -1, 'acoustic']
# Linea Destino: [1, 0.27, 5.32555, 1, -2.7189, -1, 'acoustic']
# Linea Destino: [1, 0.52, 3.6511, 1, -2.678666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.41, 2.3268666666666666, 1, -6.779233333333334, -1, 'acoustic']
# Linea Destino: [1, 0.51, 2.976916666666667, 1, -3.5852, 1, 'acoustic']
# Linea Destino: [1, 0.48, 1.9903833333333334, 1, -3.578333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.52, 3.36475, 1, -2.9029666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.39, 3.6608833333333335, 1, -1.6060999999999999, 0, 'acoustic']
# Linea Destino: [1, 0.27, 4.656433333333333, 1, -2.5976666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.41, 3.7066666666666666, 1, -3.077433333333333, 1, 'acoustic']
# Linea Destino: [1, 0.43, 3.3371166666666667, 1, -2.3047666666666666, 1, 'acoustic']
# Linea Destino: [2, 0.45, 2.4292166666666666, 1, -4.254666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.093333333333334, 1, -0.46376666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.41, 2.5057666666666667, 1, -2.5686666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.33, 3.581, 1, -4.616366666666667, 1, 'acoustic']
# Linea Destino: [1, 0.47, 4.289833333333333, 1, -2.8333666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.48, 3.3821333333333334, 1, -3.1847666666666665, 1, 'acoustic']
# Linea Destino: [1, 0.44, 4.195333333333333, 1, -1.4941333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.64, 4.1051, 1, -1.1627666666666665, -1, 'acoustic']
# Linea Destino: [1, 0.49, 4.677533333333334, 1, -3.5844000000000005, -1, 'acoustic']
# Linea Destino: [1, 0.49, 3.40555, 1, -4.9082, 1, 'acoustic']
# Linea Destino: [1, 0.45, 3.1062166666666666, 1, -3.0593000000000004, -1, 'acoustic']
# Linea Destino: [1, 0.26, 2.8219166666666666, 1, -2.760333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.47, 4.186066666666667, 1, -3.5463000000000005, 0, 'acoustic']
# Linea Destino: [1, 0.27, 5.369, 1, -3.114433333333333, 0, 'acoustic']
# Linea Destino: [1, 0.26, 4.34755, 1, -2.789766666666667, 0, 'acoustic']
# Linea Destino: [1, 0.48, 5.114216666666667, 1, -3.8718000000000004, 1, 'acoustic']
# Linea Destino: [1, 0.59, 2.7006666666666668, 1, -3.281733333333333, 1, 'acoustic']
# Linea Destino: [1, 0.26, 3.3311, 1, -3.5955, 0, 'acoustic']
# Linea Destino: [1, 0.53, 4.190883333333334, 1, -3.4003333333333328, 1, 'acoustic']
# Linea Destino: [3, 0.26, 2.496383333333333, 1, -3.5578, 1, 'acoustic']
# Linea Destino: [1, 0.26, 3.5150166666666665, 1, -3.204133333333333, -1, 'acoustic']
# Linea Destino: [1, 0.26, 5.101533333333333, 1, -2.999866666666667, 0, 'acoustic']
# Linea Destino: [1, 0.48, 3.918, 1, -2.1622666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.61, 3.576, 1, -1.6122666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.27, 1.1751, -1, -3.42, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.134, 1, -3.1005000000000003, 0, 'acoustic']
# Linea Destino: [1, 0.5, 2.255333333333333, 1, -1.6188333333333336, 1, 'acoustic']
# Linea Destino: [1, 0.26, 1.8606833333333332, -1, -2.1065, 1, 'acoustic']
# Linea Destino: [1, 0.27, 2.7230833333333333, 1, -1.9787, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.014433333333334, 1, -1.8077666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.26, 1.4771, 1, -0.5643333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.49, 3.816, 1, -1.995, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.4525166666666665, -1, -2.9949999999999997, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.7048833333333335, -1, -1.4447333333333334, -1, 'acoustic']
# Linea Destino: [1, 0.26, 2.648433333333333, 1, -1.2566666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.47, 3.033333333333333, 1, -1.2863333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.33, 9.6344, 1, -2.790566666666667, -1, 'acoustic']
# Linea Destino: [2, 0.57, 4.12805, 1, -3.582933333333333, 1, 'acoustic']
# Linea Destino: [1, 0.44, 3.2924333333333333, 1, -2.0910333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.58, 2.731883333333333, 1, -3.845266666666667, -1, 'acoustic']
# Linea Destino: [1, 0.48, 3.286583333333333, 1, -4.967266666666666, 1, 'acoustic']
# Linea Destino: [1, 0.39, 3.5037666666666665, 1, -1.5848666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.45, 3.494483333333333, 1, -3.5583666666666662, 1, 'acoustic']
# Linea Destino: [1, 0.49, 3.44085, 1, -2.6820000000000004, -1, 'acoustic']
# Linea Destino: [2, 0.44, 4.20945, 1, -3.8378333333333337, 1, 'acoustic']
# Linea Destino: [1, 0.44, 3.6140166666666667, 1, -4.912166666666667, 0, 'acoustic']
# Linea Destino: [4, 0.51, 4.238433333333333, 1, -4.324800000000001, 1, 'acoustic']
# Linea Destino: [1, 0.41, 0.99705, 1, -6.525033333333333, 1, 'acoustic']
# Linea Destino: [1, 0.58, 3.111, 1, -3.5778666666666665, 1, 'acoustic']
# Linea Destino: [2, 0.54, 2.5269666666666666, 1, -3.9995333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.41, 3.790216666666667, 1, -3.3667000000000002, 0, 'acoustic']
# Linea Destino: [1, 0.46, 1.9813, 1, -1.9632666666666667, 0, 'acoustic']
# Linea Destino: [2, 0.26, 4.226666666666667, 1, -2.1576333333333335, 1, 'acoustic']
# Linea Destino: [2, 0.56, 4.325966666666667, 1, -3.8028333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.27, 4.64355, 1, -0.8912, 1, 'acoustic']
# Linea Destino: [1, 0.46, 4.2951, 1, -3.362966666666667, 1, 'acoustic']
# Linea Destino: [1, 0.26, 2.9602166666666667, 1, -3.301066666666667, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.9611, 1, -1.8196333333333332, 0, 'acoustic']
# Linea Destino: [2, 0.52, 4.912266666666667, 1, -2.5213, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.304516666666666, 1, -1.4996, 1, 'acoustic']
# Linea Destino: [1, 0.55, 3.3845, 1, -1.3729666666666664, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.3453333333333335, 1, -1.542666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.51, 4.7825, 1, -1.63, 0, 'acoustic']
# Linea Destino: [1, 0.51, 3.53955, 1, -1.4980666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.49, 2.3124666666666664, 1, -6.097, 1, 'acoustic']
# Linea Destino: [1, 0.47, 3.6233333333333335, 1, -2.2715, -1, 'acoustic']
# Linea Destino: [1, 0.58, 2.8333333333333335, 1, -4.250766666666666, 0, 'acoustic']
# Linea Destino: [1, 0.27, 6.3745666666666665, 1, -2.8414, 0, 'acoustic']
# Linea Destino: [1, 0.58, 2.6266666666666665, 1, -3.458066666666667, 0, 'acoustic']
# Linea Destino: [1, 0.26, 3.6933, 1, -1.5815000000000001, 0, 'acoustic']
# Linea Destino: [1, 0.27, 2.8924333333333334, 1, -2.753966666666667, 1, 'acoustic']
# Linea Destino: [1, 0.26, 2.4935, 1, -3.8675, -1, 'acoustic']
# Linea Destino: [1, 0.27, 4.086, 1, -3.174633333333334, -1, 'acoustic']
# Linea Destino: [1, 0.27, 2.7168833333333335, -1, -2.9989333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.26, 3.3644333333333334, 1, -1.4958333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.58, 3.4627, 1, -2.337, 0, 'acoustic']
# Linea Destino: [1, 0.27, 1.7366666666666666, 1, -2.1375333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.65365, 1, -1.9883333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.26, 1.2250166666666666, 1, -0.6700333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.26, 2.804, 1, -0.8699333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.27, 2.5073166666666666, -1, -2.783, -1, 'acoustic']
# Linea Destino: [1, 0.26, 6.73185, -1, -3.035433333333333, -1, 'acoustic']
# Linea Destino: [2, 0.29, 4.481766666666666, 1, -1.8469666666666669, 1, 'acoustic']
# Linea Destino: [1, 0.26, 3.88025, 1, -1.2465, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.515333333333333, 1, -2.2722, 1, 'acoustic']
# Linea Destino: [1, 0.42, 2.8452, 1, -2.4213666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.51, 3.13635, 1, -2.774833333333333, 1, 'acoustic']
# Linea Destino: [1, 0.53, 2.3523666666666667, 1, -2.6401333333333334, 0, 'acoustic']
# Linea Destino: [1, 0.66, 2.98245, 1, -2.5551999999999997, 0, 'acoustic']
# Linea Destino: [1, 0.51, 3.031616666666667, 1, -3.7586999999999997, -1, 'acoustic']
# Linea Destino: [2, 0.4, 3.6296166666666667, 1, -3.282666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.38, 2.9872666666666667, 1, -4.439633333333334, 1, 'acoustic']
# Linea Destino: [1, 0.43, 4.200216666666667, 1, -4.192666666666667, -1, 'acoustic']
# Linea Destino: [1, 0.44, 3.522666666666667, 1, -4.253500000000001, -1, 'acoustic']
# Linea Destino: [1, 0.47, 3.1622, 1, -2.1119, 0, 'acoustic']
# Linea Destino: [1, 0.27, 3.486666666666667, 1, -1.1804, 1, 'acoustic']
# Linea Destino: [1, 0.52, 4.333333333333333, 1, -3.6403, -1, 'acoustic']
# Linea Destino: [1, 0.43, 3.0303166666666668, 1, -6.098733333333333, 0, 'acoustic']
# Linea Destino: [1, 0.56, 3.5031, 1, -2.1362666666666668, 0, 'acoustic']
# Linea Destino: [1, 0.48, 4.4551, 1, -3.6834333333333333, 1, 'acoustic']
# Linea Destino: [2, 0.43, 4.06955, 1, -2.3148333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.33, 4.210466666666667, 1, -2.3145666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.25, 4.70645, 1, -2.910533333333333, 0, 'acoustic']
# Linea Destino: [2, 0.47, 4.7211, 1, -3.7494, -1, 'acoustic']
# Linea Destino: [1, 0.39, 4.686883333333333, 1, -3.0464333333333333, 0, 'acoustic']
# Linea Destino: [2, 0.47, 3.5227333333333335, 1, -3.2484, 0, 'acoustic']
# Linea Destino: [1, 0.5, 2.7877666666666667, 1, -4.201666666666666, 0, 'acoustic']
# Linea Destino: [1, 0.27, 3.7222166666666667, 1, -1.0932000000000002, -1, 'acoustic']
# Linea Destino: [1, 0.47, 2.97765, 1, -0.8136666666666666, 1, 'acoustic']
# Linea Destino: [1, 0.26, 5.010433333333333, 1, -0.9211, 0, 'acoustic']
# Linea Destino: [1, 0.51, 6.016883333333333, 1, -3.8623999999999996, 0, 'acoustic']
# Linea Destino: [1, 0.26, 2.225, 1, -6.599900000000001, 1, 'acoustic']
# Linea Destino: [3, 0.37, 3.5603333333333333, 1, -3.1269666666666667, 0, 'acoustic']
# Linea Destino: [1, 0.25, 3.1318, 1, -2.2364666666666664, 1, 'acoustic']
# Linea Destino: [1, 0.45, 3.9366666666666665, 1, -3.024433333333334, 1, 'acoustic']
# Linea Destino: [1, 0.25, 4.03335, 1, -5.1488000000000005, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.1128833333333334, 1, -4.247366666666666, -1, 'acoustic']
# Linea Destino: [1, 0.44, 3.8364333333333334, 1, -2.2382666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.27, 3.3022666666666667, 1, -1.5282333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.25, 2.11585, 1, -4.029633333333333, -1, 'acoustic']
# Linea Destino: [1, 0.24, 3.0, 1, -1.6130666666666666, -1, 'acoustic']
# Linea Destino: [1, 0.27, 1.7384333333333333, -1, -1.3676333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.25, 3.7797666666666667, 1, -2.029333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.6805333333333334, 1, -2.493733333333333, 0, 'acoustic']
# Linea Destino: [1, 0.27, 2.4869, -1, -2.8304666666666667, 1, 'acoustic']
# Linea Destino: [2, 0.25, 2.3529333333333335, 1, -1.4097999999999997, 0, 'acoustic']
# Linea Destino: [1, 0.27, 3.84485, -1, -1.3947333333333336, 0, 'acoustic']
# Linea Destino: [1, 0.28, 2.568433333333333, 1, -4.293633333333333, 0, 'acoustic']
# Linea Destino: [1, 0.26, 4.568883333333333, 1, -2.735333333333333, 1, 'acoustic']
# Linea Destino: [2, 0.25, 3.492166666666667, 1, -2.3190333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.395033333333333, 1, -4.2215, 1, 'acoustic']
# Linea Destino: [1, 0.27, 3.2877666666666667, -1, -2.549533333333333, 1, 'acoustic']
# Linea Destino: [2, 0.26, 2.6611, 1, -1.2409333333333332, 0, 'acoustic']
# Linea Destino: [2, 0.25, 2.372716666666667, 1, -2.8884000000000003, 0, 'acoustic']
# Linea Destino: [1, 0.25, 2.5342166666666666, 1, -0.9934333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.5, 2.683333333333333, -1, -2.4577999999999998, -1, 'acoustic']
# Linea Destino: [1, 0.43, 3.8457666666666666, 1, -2.696766666666667, 1, 'acoustic']
# Linea Destino: [1, 0.46, 3.6928, 1, -5.0200000000000005, 1, 'acoustic']
# Linea Destino: [1, 0.34, 3.7444333333333333, 1, -3.6136000000000004, 0, 'acoustic']
# Linea Destino: [1, 0.35, 3.314216666666667, 1, -3.0057999999999994, 0, 'acoustic']
# Linea Destino: [1, 0.26, 3.2293666666666665, 1, -1.9216666666666669, -1, 'acoustic']
# Linea Destino: [1, 0.45, 3.966833333333333, 1, -4.3435999999999995, 0, 'acoustic']
# Linea Destino: [1, 0.4, 3.935, 1, -2.4220333333333333, 0, 'acoustic']
# Linea Destino: [1, 0.51, 4.141383333333334, 1, -2.5044, 1, 'acoustic']
# Linea Destino: [2, 0.47, 1.2027833333333333, 1, -7.046900000000001, -1, 'acoustic']
# Linea Destino: [1, 0.46, 3.3724666666666665, 1, -2.6779333333333333, -1, 'acoustic']
# Linea Destino: [1, 0.45, 4.1284, 1, -2.424033333333333, 1, 'acoustic']
# Linea Destino: [1, 0.55, 2.782383333333333, 1, -4.712433333333333, 0, 'acoustic']
# Linea Destino: [1, 0.26, 5.4451, 1, -1.7950333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.48, 3.8884333333333334, 1, -2.599666666666667, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.558, 1, -2.0184, 1, 'acoustic']
# Linea Destino: [1, 0.45, 3.4442166666666667, 1, -2.1020666666666665, 0, 'acoustic']
# Linea Destino: [1, 0.27, 4.387766666666667, 1, -3.9767333333333332, 0, 'acoustic']
# Linea Destino: [1, 0.54, 3.1018166666666667, 1, -1.6726666666666665, 0, 'acoustic']
# Linea Destino: [1, 0.37, 3.1917666666666666, 1, -6.1526, -1, 'acoustic']
# Linea Destino: [2, 0.5, 3.6964333333333332, 1, -3.5611, -1, 'acoustic']
# Linea Destino: [1, 0.27, 3.9811, 1, -2.5779666666666667, 1, 'acoustic']
# Linea Destino: [2, 0.52, 3.565, 1, -2.047266666666667, -1, 'acoustic']
# Linea Destino: [2, 0.51, 2.2745, 1, -2.0452, 1, 'acoustic']
# Linea Destino: [1, 0.25, 6.21, 1, -5.919599999999999, 1, 'acoustic']
# Linea Destino: [1, 0.26, 4.348216666666667, 1, -1.2993999999999999, 0, 'acoustic']
# Linea Destino: [1, 0.26, 3.9166666666666665, 1, -1.4270666666666665, 0, 'acoustic']
# Linea Destino: [1, 0.38, 4.550433333333333, 1, -4.7343, -1, 'acoustic']
# Linea Destino: [1, 0.25, 5.7419, 1, -2.3823333333333334, 1, 'acoustic']
# Linea Destino: [1, 0.47, 3.9473333333333334, 1, -3.896733333333333, 1, 'acoustic']
# Linea Destino: [1, 0.25, 5.097766666666667, 1, -4.417933333333334, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.6097333333333332, 1, -4.246266666666666, 1, 'acoustic']
# Linea Destino: [1, 0.25, 4.284233333333333, 1, -1.4434333333333333, 1, 'acoustic']
# Linea Destino: [1, 0.25, 2.7999833333333335, 1, -2.4604333333333335, -1, 'acoustic']
# Linea Destino: [1, 0.26, 3.6702166666666667, 1, -1.8944, 1, 'acoustic']
# Linea Destino: [1, 0.25, 4.08035, 1, -2.232066666666667, 0, 'acoustic']
# Linea Destino: [1, 0.25, 3.772, 1, -3.4739333333333335, 1, 'acoustic']
# Linea Destino: [1, 0.26, 3.1925333333333334, -1, -1.9747333333333332, 0, 'acoustic']
# Linea Destino: [1, 0.26, 2.5557, -1, -2.2798333333333334, 1, 'acoustic']
# ...
# Linea Destino: [1, 0.6, 3.7369666666666665, 1, -1.3793333333333333, 1, 'anime']
# Linea Destino: [1, 0.5, 2.5833333333333335, 1, -4.475666666666667, -1, 'anime']
# Linea Destino: [1, 0.53, 4.00955, 1, -1.9153666666666667, 1, 'anime']
# Linea Destino: [1, 0.58, 5.213766666666666, 1, -1.3145333333333333, 1, 'anime']
# Linea Destino: [1, 0.45, 2.700616666666667, 1, -2.6550666666666665, 0, 'anime']
# Linea Destino: [1, 0.63, 3.936, 1, -1.2611333333333332, 1, 'anime']
# Linea Destino: [1, 0.57, 4.438466666666667, 1, -1.0562, 1, 'anime']
# Linea Destino: [1, 0.53, 2.8034833333333333, 1, -2.1198333333333337, -1, 'anime']
# Linea Destino: [1, 0.61, 1.9387166666666666, -1, -2.5427, 0, 'anime']
# Linea Destino: [1, 0.54, 4.421766666666667, 1, -1.1332, 1, 'anime']
# Linea Destino: [1, 0.53, 3.421333333333333, 1, -1.6426999999999998, 1, 'anime']
# Linea Destino: [1, 0.58, 4.11355, 1, -0.05129999999999999, 1, 'anime']
# Linea Destino: [2, 0.47, 3.770383333333333, 1, -1.1696666666666666, 1, 'anime']
# Linea Destino: [1, 0.59, 3.6531166666666666, 1, -1.275, 1, 'anime']
# Linea Destino: [1, 0.49, 5.106216666666667, 1, -3.1561999999999997, -1, 'anime']
# Linea Destino: [1, 0.49, 2.0380833333333332, 1, -3.5119666666666673, 1, 'anime']
# Linea Destino: [1, 0.62, 1.8202666666666667, 1, -5.173433333333333, -1, 'anime']
# Linea Destino: [1, 0.45, 1.6513166666666668, 1, -1.3161666666666665, 0, 'anime']
# Linea Destino: [1, 0.55, 4.179283333333333, 1, -2.5687333333333338, 1, 'anime']
# Linea Destino: [1, 0.58, 4.158, 1, -0.5604666666666668, -1, 'anime']
# Linea Destino: [1, 0.46, 5.114, 1, -2.975633333333333, 0, 'anime']
# Linea Destino: [1, 0.45, 2.6481166666666667, 1, -3.8694666666666664, 1, 'anime']
# Linea Destino: [1, 0.49, 2.6711666666666667, 1, -2.4204333333333334, -1, 'anime']
# Linea Destino: [3, 0.5, 3.0533, -1, -2.226, -1, 'anime']
# Linea Destino: [1, 0.61, 1.8564333333333334, 1, -1.1877999999999997, 0, 'anime']
# Linea Destino: [2, 0.63, 2.2621333333333333, -1, -2.3076666666666665, 1, 'anime']
# Linea Destino: [2, 0.59, 2.1318333333333332, 1, -4.934533333333333, 1, 'anime']
# Linea Destino: [1, 0.6, 5.5324333333333335, 1, -1.8363333333333332, 1, 'anime']
# Linea Destino: [1, 0.49, 2.2991333333333333, 1, -2.1338333333333335, 0, 'anime']
# Linea Destino: [1, 0.57, 4.6029333333333335, 1, -1.224, 1, 'anime']
# Linea Destino: [1, 0.59, 1.0082833333333334, 1, -7.823333333333333, 1, 'anime']
# Linea Destino: [1, 0.59, 2.4143666666666665, 1, -2.526033333333333, 0, 'anime']
# Linea Destino: [1, 0.61, 4.111883333333333, 1, -0.3461666666666667, 1, 'anime']
# Linea Destino: [1, 0.6, 1.2959, 1, -9.3062, -1, 'anime']
# Linea Destino: [1, 0.61, 4.485333333333333, 1, -1.3023333333333333, -1, 'anime']
# Linea Destino: [1, 0.58, 1.4602, 1, -8.080733333333333, -1, 'anime']
# Linea Destino: [1, 0.58, 3.3617833333333333, 1, -1.0565, 1, 'anime']
# Linea Destino: [1, 0.58, 3.2695, 1, -1.0831000000000002, 1, 'anime']
# Linea Destino: [1, 0.59, 1.3428333333333333, 1, -8.868799999999998, -1, 'anime']
# Linea Destino: [1, 0.58, 2.0637, 1, -1.7513333333333332, 1, 'anime']
# Linea Destino: [2, 0.0, 5.6033333333333335, 1, -6.691433333333333, 0, 'anime']
# Linea Destino: [2, 0.45, 2.1597666666666666, 1, -4.3522, -1, 'anime']
# Linea Destino: [1, 0.5, 3.0584333333333333, 1, -2.7578333333333336, 1, 'anime']
# Linea Destino: [1, 0.48, 2.1662166666666667, 1, -2.9080999999999997, -1, 'anime']
# Linea Destino: [1, 0.57, 4.902683333333333, 1, -1.7360666666666666, 1, 'anime']
# Linea Destino: [1, 0.67, 4.593566666666667, 1, -0.32733333333333337, 1, 'anime']
# Linea Destino: [1, 0.61, 3.6271, 1, -0.2241, 0, 'anime']
# Linea Destino: [1, 0.59, 4.384433333333333, 1, -0.3462666666666667, 1, 'anime']
# Linea Destino: [1, 0.44, 2.80375, 1, -3.2259333333333338, 0, 'anime']
# Linea Destino: [1, 0.56, 3.6882166666666665, 1, -1.4482666666666668, 0, 'anime']
# Linea Destino: [1, 0.48, 2.7396, 1, -4.793066666666666, -1, 'anime']
# Linea Destino: [1, 0.42, 1.384, 1, -3.9059333333333335, -1, 'anime']
# Linea Destino: [1, 0.45, 2.4, 1, -2.9713333333333334, 1, 'anime']
# Linea Destino: [2, 0.56, 4.08995, 1, -1.4549, 1, 'anime']
# Linea Destino: [1, 0.53, 2.403766666666667, 1, -9.369266666666666, 1, 'anime']
# Linea Destino: [1, 0.51, 4.9126666666666665, 1, -2.0088666666666666, -1, 'anime']
# Linea Destino: [1, 0.53, 4.268416666666667, 1, -1.455066666666667, -1, 'anime']
# Linea Destino: [1, 0.61, 3.885866666666667, 1, -0.3591333333333333, 1, 'anime']
# Linea Destino: [1, 0.49, 1.5145166666666667, 1, -10.9365, 1, 'anime']
# Linea Destino: [1, 0.57, 4.088666666666667, 1, -0.5255666666666666, 1, 'anime']
# Linea Destino: [1, 0.5, 3.8311166666666665, 1, -0.973, 1, 'anime']
# Linea Destino: [1, 0.58, 3.7635, 1, -3.072333333333333, 1, 'anime']
# Linea Destino: [1, 0.46, 2.2914666666666665, 1, -2.5418666666666665, -1, 'anime']
# Linea Destino: [1, 0.59, 3.7748833333333334, 1, -1.3093, 1, 'anime']
# Linea Destino: [1, 0.53, 4.074066666666667, 1, -1.0811333333333335, -1, 'anime']
# Linea Destino: [1, 0.51, 2.221433333333333, 1, -2.8666666666666667, 0, 'anime']
# Linea Destino: [1, 0.48, 1.7549333333333332, 1, -2.0812, 1, 'anime']
# Linea Destino: [1, 0.63, 2.6878333333333333, 1, -4.656766666666667, 1, 'anime']
# Linea Destino: [1, 0.75, 4.219216666666667, 1, -1.505, 0, 'anime']
# Linea Destino: [1, 0.54, 4.846883333333333, 1, -1.1440000000000001, 1, 'anime']
# Linea Destino: [1, 0.49, 1.9353666666666667, 1, -4.1156999999999995, 1, 'anime']
# Linea Destino: [2, 0.42, 3.54645, 1, -1.4593333333333334, -1, 'anime']
# Linea Destino: [1, 0.56, 4.734666666666667, 1, -0.8147333333333333, 1, 'anime']
# Linea Destino: [1, 0.25, 2.2179333333333333, 1, -4.808000000000001, 1, 'anime']
# Linea Destino: [2, 0.49, 3.5999333333333334, 1, -1.1920000000000002, 1, 'anime']
# Linea Destino: [1, 0.25, 1.4708333333333334, 1, -5.205233333333334, 1, 'anime']
# Linea Destino: [1, 0.5, 2.74285, -1, -2.736333333333333, 1, 'anime']
# Linea Destino: [1, 0.24, 1.74175, 1, -6.832, 1, 'anime']
# Linea Destino: [1, 0.59, 4.06955, 1, -0.5793333333333334, 1, 'anime']
# Linea Destino: [1, 0.24, 1.6333333333333333, 1, -3.9297, 0, 'anime']
# Linea Destino: [1, 0.58, 1.4396666666666667, 1, -8.192033333333335, 0, 'anime']
# Linea Destino: [1, 0.23, 1.3625, 1, -4.1273333333333335, -1, 'anime']
# Linea Destino: [1, 0.23, 1.3798333333333332, 1, -5.237233333333333, 1, 'anime']
# Linea Destino: [1, 0.59, 1.2119833333333334, 1, -9.424966666666666, -1, 'anime']
# Linea Destino: [1, 0.58, 1.2086166666666667, 1, -8.071033333333334, 1, 'anime']
# Linea Destino: [1, 0.29, 2.76415, 1, -3.7395333333333336, 0, 'anime']
# Linea Destino: [1, 0.58, 0.94705, 1, -7.6569, 0, 'anime']
# Linea Destino: [1, 0.26, 1.2142833333333334, 1, -4.398433333333333, 1, 'anime']
# Linea Destino: [2, 0.59, 3.7908833333333334, 1, -1.2570000000000001, 1, 'anime']
# Linea Destino: [1, 0.61, 2.7932333333333332, 1, -1.3485333333333331, 1, 'anime']
# Linea Destino: [1, 0.42, 4.38955, 1, -0.13453333333333334, 1, 'anime']
# Linea Destino: [2, 0.47, 3.462, 1, -5.172733333333333, 0, 'anime']
# Linea Destino: [1, 0.52, 2.655, 1, -4.8960333333333335, 0, 'anime']
# Linea Destino: [1, 0.6, 3.8777666666666666, 1, -0.8203333333333335, 1, 'anime']
# Linea Destino: [1, 0.49, 2.0997666666666666, 1, -2.715433333333334, 1, 'anime']
# Linea Destino: [1, 0.42, 1.87555, 1, -2.2267333333333332, 1, 'anime']
# Linea Destino: [1, 0.49, 1.9285833333333333, 1, -6.218666666666667, 1, 'anime']
# Linea Destino: [1, 0.56, 4.148883333333333, 1, -0.5684, 1, 'anime']
# Linea Destino: [1, 0.4, 3.2520166666666666, 1, -3.255933333333333, 1, 'anime']
# Linea Destino: [1, 0.55, 3.8668833333333335, 1, -0.5325333333333333, 1, 'anime']
# Linea Destino: [1, 0.59, 3.812666666666667, 1, -1.4917, 1, 'anime']
# Linea Destino: [1, 0.5, 1.68925, 1, -5.700333333333333, 1, 'anime']
# Linea Destino: [1, 0.57, 2.98555, 1, -0.8089000000000001, 0, 'anime']
# Linea Destino: [1, 0.56, 1.4997166666666666, 1, -1.1778, 1, 'anime']
# Linea Destino: [1, 0.5, 4.018, 1, -1.0236666666666667, 1, 'anime']
# Linea Destino: [1, 0.55, 4.1031, 1, -1.0359333333333334, 1, 'anime']
# Linea Destino: [1, 0.45, 1.4423166666666667, -1, -3.8186666666666667, 1, 'anime']
# Linea Destino: [1, 0.48, 2.32555, 1, -5.3429, 1, 'anime']
# Linea Destino: [1, 0.53, 3.5997333333333335, 1, -0.6955333333333332, 0, 'anime']
# Linea Destino: [1, 0.5, 3.6168833333333335, 1, -0.7790666666666666, 1, 'anime']
# Linea Destino: [1, 0.55, 4.472216666666666, 1, -2.6083, 1, 'anime']
# Linea Destino: [1, 0.57, 4.91555, 1, -1.217466666666667, -1, 'anime']
# Linea Destino: [1, 0.49, 2.55, 1, -5.112433333333334, 1, 'anime']
# Linea Destino: [1, 0.59, 3.114533333333333, 1, -0.991, 0, 'anime']
# Linea Destino: [1, 0.57, 5.13155, 1, -2.1226666666666665, 1, 'anime']
# Linea Destino: [1, 0.52, 5.178216666666667, 1, -1.8200999999999998, 1, 'anime']
# Linea Destino: [1, 0.47, 4.958216666666667, 1, -3.167866666666667, 1, 'anime']
# Linea Destino: [1, 0.51, 4.23155, 1, -1.3152, 1, 'anime']
# Linea Destino: [2, 0.49, 3.042, 1, -0.8766666666666666, 1, 'anime']
# Linea Destino: [1, 0.54, 3.7037666666666667, 1, -0.6895333333333333, 1, 'anime']
# Linea Destino: [1, 0.56, 2.797, 1, -1.7075333333333333, -1, 'anime']
# Linea Destino: [1, 0.58, 3.398216666666667, 1, -0.969, 1, 'anime']
# Linea Destino: [1, 0.56, 4.596666666666667, 1, -1.1062, 1, 'anime']
# Linea Destino: [1, 0.41, 4.250216666666667, 1, -2.5622, 1, 'anime']
# Linea Destino: [3, 0.49, 3.1107, 1, -0.8046666666666668, 1, 'anime']
# Linea Destino: [1, 0.52, 2.405133333333333, -1, -0.3383333333333334, 1, 'anime']
# Linea Destino: [1, 0.58, 1.13405, 1, -9.012566666666666, 1, 'anime']
# Linea Destino: [1, 0.58, 1.0508166666666667, 1, -6.953300000000001, 1, 'anime']
# Linea Destino: [1, 0.57, 1.5777, 1, -9.4375, 1, 'anime']
# Linea Destino: [1, 0.58, 1.2860333333333334, 1, -9.531733333333333, -1, 'anime']
# Linea Destino: [1, 0.57, 1.3905333333333334, 1, -8.030866666666666, -1, 'anime']
# Linea Destino: [1, 0.58, 0.9384166666666667, 1, -8.4944, -1, 'anime']
# Linea Destino: [1, 0.57, 1.4282166666666667, 1, -8.2878, -1, 'anime']
# Linea Destino: [1, 0.4, 3.9503166666666667, 1, -4.098566666666667, 1, 'anime']
# Linea Destino: [1, 0.41, 5.322216666666667, 1, -1.0778999999999999, -1, 'anime']
# Linea Destino: [1, 0.6, 5.4473666666666665, 1, -0.9661666666666667, -1, 'anime']
# Linea Destino: [1, 0.57, 1.6214166666666667, 1, -8.265333333333333, -1, 'anime']
# Linea Destino: [1, 0.57, 1.5486166666666668, 1, -7.619700000000001, 1, 'anime']
# Linea Destino: [1, 0.58, 1.15805, 1, -8.556566666666667, 1, 'anime']
# Linea Destino: [1, 0.41, 4.402666666666667, 1, -0.4122333333333333, 1, 'anime']
# Linea Destino: [1, 0.58, 1.2789, 1, -9.8452, -1, 'anime']
# Linea Destino: [1, 0.5, 2.9211, 1, -5.593566666666667, -1, 'anime']
# Linea Destino: [1, 0.58, 4.360883333333334, 1, -0.7976666666666667, 1, 'anime']
# Linea Destino: [3, 0.48, 4.05555, 1, -1.6716666666666666, 1, 'anime']
# Linea Destino: [1, 0.6, 3.4328833333333333, 1, -1.016133333333333, 1, 'anime']
# Linea Destino: [1, 0.55, 3.730766666666667, 1, -1.5827000000000002, 0, 'anime']
# Linea Destino: [1, 0.56, 3.79955, 1, -0.6087333333333333, 1, 'anime']
# Linea Destino: [1, 0.51, 2.9093333333333335, 1, -4.2056000000000004, -1, 'anime']
# Linea Destino: [1, 0.36, 4.5486, 1, 0.41450000000000004, 1, 'anime']
# Linea Destino: [1, 0.51, 1.5396666666666667, 1, -2.8221000000000003, 1, 'anime']
# Linea Destino: [1, 0.44, 3.168, 1, -1.2596666666666667, 1, 'anime']
# Linea Destino: [1, 0.5, 2.75, 1, -5.505933333333332, -1, 'anime']
# Linea Destino: [1, 0.52, 4.121766666666667, 1, -0.9466000000000001, 1, 'anime']
# Linea Destino: [1, 0.43, 2.9, 1, -1.8482333333333332, 0, 'anime']
# Linea Destino: [1, 0.48, 4.7951, 1, -1.8524333333333336, 1, 'anime']
# Linea Destino: [1, 0.45, 2.926816666666667, 1, -3.3229333333333333, 1, 'anime']
# Linea Destino: [1, 0.58, 4.069333333333334, 1, -0.9493333333333333, -1, 'anime']
# Linea Destino: [1, 0.56, 3.7651, 1, -1.2875333333333334, 1, 'anime']
# Linea Destino: [1, 0.48, 1.97435, 1, -3.2243, -1, 'anime']
# Linea Destino: [1, 0.57, 3.713766666666667, 1, -0.786, 1, 'anime']
# Linea Destino: [1, 0.52, 5.8966666666666665, 1, -1.5126333333333333, 1, 'anime']
# Linea Destino: [1, 0.45, 2.8249333333333335, 1, -2.3507666666666664, 0, 'anime']
# Linea Destino: [1, 0.49, 1.5, 1, -0.7896666666666667, -1, 'anime']
# Linea Destino: [1, 0.6, 3.898216666666667, 1, -0.9873333333333333, 1, 'anime']
# Linea Destino: [1, 0.52, 4.071766666666667, 1, -0.6832666666666668, -1, 'anime']
# Linea Destino: [1, 0.58, 3.784666666666667, 1, -0.8284666666666668, -1, 'anime']
# Linea Destino: [1, 0.42, 3.02955, -1, -0.8776666666666667, 1, 'anime']
# Linea Destino: [1, 0.53, 4.48385, 1, -0.9059666666666667, -1, 'anime']
# Linea Destino: [1, 0.54, 4.066, 1, -0.6736666666666667, 1, 'anime']
# Linea Destino: [1, 0.56, 4.636433333333334, 1, -1.2567333333333333, 1, 'anime']
# Linea Destino: [1, 0.6, 1.9269333333333334, 1, -6.545633333333334, -1, 'anime']
# Linea Destino: [1, 0.47, 3.6280166666666664, 1, -2.767533333333333, -1, 'anime']
# Linea Destino: [1, 0.53, 5.091816666666666, 1, -1.9328666666666667, 1, 'anime']
# Linea Destino: [1, 0.49, 3.17125, 1, -5.6129999999999995, 1, 'anime']
# Linea Destino: [1, 0.41, 2.6134666666666666, 1, -1.227, -1, 'anime']
# Linea Destino: [1, 0.52, 4.062216666666667, 1, -0.5405, 1, 'anime']
# Linea Destino: [1, 0.64, 2.9751, 1, -5.818899999999999, -1, 'anime']
# Linea Destino: [1, 0.46, 4.106883333333333, 1, -2.8592, 1, 'anime']
# Linea Destino: [1, 0.59, 3.00555, 1, -5.036300000000001, 0, 'anime']
# Linea Destino: [1, 0.47, 4.950433333333334, 1, -2.7891999999999997, 1, 'anime']
# Linea Destino: [1, 0.54, 4.452, 1, -2.194733333333333, 1, 'anime']
# Linea Destino: [1, 0.49, 1.7456, 1, -3.2741000000000007, -1, 'anime']
# Linea Destino: [1, 0.44, 2.9344833333333336, 1, -2.2979666666666665, 1, 'anime']
# Linea Destino: [1, 0.54, 1.5015, 1, -1.3598999999999997, 1, 'anime']
# Linea Destino: [2, 0.42, 3.3201, 1, -1.4606666666666666, 0, 'anime']
# Linea Destino: [1, 0.56, 2.2913833333333335, 1, -3.3982999999999994, 1, 'anime']
# Linea Destino: [4, 0.51, 2.4899666666666667, -1, -2.6706333333333334, 1, 'anime']
# Linea Destino: [1, 0.56, 3.1567, 1, -0.7805666666666666, 0, 'anime']
# Linea Destino: [1, 0.58, 1.7602666666666666, 1, -3.4613666666666667, 1, 'anime']
# Linea Destino: [1, 0.41, 3.0031, 1, -0.8068666666666666, 1, 'anime']
# Linea Destino: [1, 0.4, 4.532883333333333, 1, -4.280233333333333, 1, 'anime']
# Linea Destino: [1, 0.56, 3.5412666666666666, 1, -1.7758, -1, 'anime']
# Linea Destino: [1, 0.43, 4.927766666666667, 1, -1.6906666666666663, -1, 'anime']
# Linea Destino: [1, 0.48, 3.5813333333333333, 1, -1.7943333333333333, 0, 'anime']
# Linea Destino: [1, 0.45, 4.61, 1, -2.8120666666666665, -1, 'anime']
# Linea Destino: [1, 0.5, 4.015766666666667, 1, -2.7184333333333335, 1, 'anime']
# Linea Destino: [1, 0.5, 2.124433333333333, 1, -2.747533333333333, 1, 'anime']
# Linea Destino: [1, 0.35, 3.3604333333333334, 1, -4.481666666666667, -1, 'anime']
# Linea Destino: [1, 0.49, 0.8422166666666666, 1, -7.388000000000001, 1, 'anime']
# Linea Destino: [1, 0.53, 1.5631, 1, -1.6177, 1, 'anime']
# Linea Destino: [1, 0.42, 1.968, 1, -1.7965333333333333, 0, 'anime']
# Linea Destino: [1, 0.57, 3.6052833333333334, 1, -4.6784, 1, 'anime']
# Linea Destino: [1, 0.49, 3.4833333333333334, 1, -1.0296666666666667, 0, 'anime']
# Linea Destino: [1, 0.59, 3.8044333333333333, 1, -0.6190000000000001, -1, 'anime']
# Linea Destino: [1, 0.48, 2.1343, 1, -0.7153333333333333, 1, 'anime']
# Linea Destino: [1, 0.47, 3.07935, 1, -5.548566666666667, 1, 'anime']
# Linea Destino: [1, 0.51, 1.1157666666666666, 1, -3.5217333333333336, 0, 'anime']
# Linea Destino: [1, 0.57, 4.162433333333333, 1, -0.4706666666666666, 1, 'anime']
# Linea Destino: [1, 0.5, 3.2611, 1, -1.5580666666666667, 1, 'anime']
# Linea Destino: [1, 0.56, 3.4202166666666667, 1, -1.2545, 0, 'anime']
# Linea Destino:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-74bba246b27c> in <module>
#      38       lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]
#      39
# ---> 40       print('Linea Destino:', lineaDestino)
#      41
#      42 #</SOL>
#
# KeyboardInterrupt:

# %% [markdown]
# ### Paso 4
#
# Juntamos el paso 3 con el escribir en un nuevo fichero al mismo tiempo.

# %%
with open('SpotyDASH.csv', 'w', newline='') as csvfile: #El CSV no se puede llamar igual
  spotiWriter = csv.writer(csvfile, delimiter=',')

  spotiWriter.writerow( ['numArtistas', 'popularidad', 'duracion', 'explicito', 'polaridad', 'tempo', 'genero'] )


  #TABULAMOS TODO DE PASO 3... 
  #<SOL>
  with open('dataset.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',') #delimiter = Separadoe
    next(spamreader) #Tema cursores, ficheros y cabecera CSV...
    for lineaOrigen in spamreader:  
      #Pego el código que me interesa...
      numArtistas = 1
      if (len( lineaOrigen[2].split(';') ) > 0 ):
        numArtistas = len( lineaOrigen[2].split(';') ) 

      explicito = lineaOrigen[7]
      if(explicito[0] == 'T'):
          explicito = -1
      elif(explicito[0] == 'F'):
          explicito = 1
      else:
        explicito = 0

      tempo = float(lineaOrigen[-3])
      if(tempo == 128):
        tempo = 10
      elif(tempo > 120):
        tempo = 1
      elif(tempo <= 120 and tempo > 100):
        tempo = 0
      elif(tempo <= 100):
        tempo = -1

      popularidad = int(lineaOrigen[5]) / 100

      duracion = int(lineaOrigen[6]) / (60 * 1000) 

      polaridad = (float(lineaOrigen[8]) + float(lineaOrigen[11]) + float(lineaOrigen[13]) )/3 

      genero = lineaOrigen[-1]

      lineaDestino = [numArtistas, popularidad, duracion, explicito, polaridad, tempo, genero]

      #</SOL>
      spotiWriter.writerow( lineaDestino ) #AÑADIMOS EL WRITEROW()

# %% [markdown]
# > **Ejercicio**: Para acabar, busca tu fichero generado, descárgalo y comprueba que todo está como esperábamos.
